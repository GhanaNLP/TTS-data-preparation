# %% [markdown]
# # SETUP REQUIREMENTS

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install git+https://github.com/MahmoudAshraf97/ctc-forced-aligner.git
# !pip install pydub datasets
# Out:
# Collecting git+https://github.com/MahmoudAshraf97/ctc-forced-aligner.git
#   Cloning https://github.com/MahmoudAshraf97/ctc-forced-aligner.git to /tmp/pip-req-build-jtn8nnm8
#   Running command git clone --filter=blob:none --quiet https://github.com/MahmoudAshraf97/ctc-forced-aligner.git /tmp/pip-req-build-jtn8nnm8
#   Resolved https://github.com/MahmoudAshraf97/ctc-forced-aligner.git to commit 1f0a5f860d3d9daf3d94edb1c7d18f90d1702e5b
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting uroman (from ctc-forced-aligner==0.3.0)
#   Downloading uroman-1.3.1.1-py3-none-any.whl.metadata (18 kB)
# Requirement already satisfied: nltk in /usr/local/lib/python3.12/dist-packages (from ctc-forced-aligner==0.3.0) (3.9.1)
# Requirement already satisfied: torch in /usr/local/lib/python3.12/dist-packages (from ctc-forced-aligner==0.3.0) (2.8.0+cu126)
# Requirement already satisfied: torchaudio in /usr/local/lib/python3.12/dist-packages (from ctc-forced-aligner==0.3.0) (2.8.0+cu126)
# Requirement already satisfied: transformers>=4.34 in /usr/local/lib/python3.12/dist-packages (from ctc-forced-aligner==0.3.0) (4.56.0)
# Collecting Unidecode (from ctc-forced-aligner==0.3.0)
#   Downloading Unidecode-1.4.0-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from transformers>=4.34->ctc-forced-aligner==0.3.0) (3.19.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.34.0 in /usr/local/lib/python3.12/dist-packages (from transformers>=4.34->ctc-forced-aligner==0.3.0) (0.34.4)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from transformers>=4.34->ctc-forced-aligner==0.3.0) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from transformers>=4.34->ctc-forced-aligner==0.3.0) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from transformers>=4.34->ctc-forced-aligner==0.3.0) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers>=4.34->ctc-forced-aligner==0.3.0) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from transformers>=4.34->ctc-forced-aligner==0.3.0) (2.32.4)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers>=4.34->ctc-forced-aligner==0.3.0) (0.22.0)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from transformers>=4.34->ctc-forced-aligner==0.3.0) (0.6.2)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.12/dist-packages (from transformers>=4.34->ctc-forced-aligner==0.3.0) (4.67.1)
# Requirement already satisfied: click in /usr/local/lib/python3.12/dist-packages (from nltk->ctc-forced-aligner==0.3.0) (8.2.1)
# Requirement already satisfied: joblib in /usr/local/lib/python3.12/dist-packages (from nltk->ctc-forced-aligner==0.3.0) (1.5.2)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch->ctc-forced-aligner==0.3.0) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch->ctc-forced-aligner==0.3.0) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch->ctc-forced-aligner==0.3.0) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch->ctc-forced-aligner==0.3.0) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch->ctc-forced-aligner==0.3.0) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from torch->ctc-forced-aligner==0.3.0) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch->ctc-forced-aligner==0.3.0) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch->ctc-forced-aligner==0.3.0) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch->ctc-forced-aligner==0.3.0) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch->ctc-forced-aligner==0.3.0) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch->ctc-forced-aligner==0.3.0) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch->ctc-forced-aligner==0.3.0) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch->ctc-forced-aligner==0.3.0) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch->ctc-forced-aligner==0.3.0) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch->ctc-forced-aligner==0.3.0) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch->ctc-forced-aligner==0.3.0) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in /usr/local/lib/python3.12/dist-packages (from torch->ctc-forced-aligner==0.3.0) (2.27.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch->ctc-forced-aligner==0.3.0) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch->ctc-forced-aligner==0.3.0) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch->ctc-forced-aligner==0.3.0) (1.11.1.6)
# Requirement already satisfied: triton==3.4.0 in /usr/local/lib/python3.12/dist-packages (from torch->ctc-forced-aligner==0.3.0) (3.4.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers>=4.34->ctc-forced-aligner==0.3.0) (1.1.9)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch->ctc-forced-aligner==0.3.0) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch->ctc-forced-aligner==0.3.0) (3.0.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->transformers>=4.34->ctc-forced-aligner==0.3.0) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->transformers>=4.34->ctc-forced-aligner==0.3.0) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->transformers>=4.34->ctc-forced-aligner==0.3.0) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->transformers>=4.34->ctc-forced-aligner==0.3.0) (2025.8.3)
# Downloading Unidecode-1.4.0-py3-none-any.whl (235 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 235.8/235.8 kB 9.0 MB/s eta 0:00:00
# Downloading uroman-1.3.1.1-py3-none-any.whl (930 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 930.7/930.7 kB 44.8 MB/s eta 0:00:00
# Building wheels for collected packages: ctc-forced-aligner
#   Building wheel for ctc-forced-aligner (pyproject.toml) ... done
#   Created wheel for ctc-forced-aligner: filename=ctc_forced_aligner-0.3.0-cp312-cp312-linux_x86_64.whl size=96942 sha256=16f7878255730597c454c757427749451c17f7344eae30d0c840e6d4be647e22
#   Stored in directory: /tmp/pip-ephem-wheel-cache-9mzaac7_/wheels/3c/d4/13/bf2c0f2e6af318a8f505400dfb51fa789db37aab64222656dd
# Successfully built ctc-forced-aligner
# Installing collected packages: uroman, Unidecode, ctc-forced-aligner
# Successfully installed Unidecode-1.4.0 ctc-forced-aligner-0.3.0 uroman-1.3.1.1
# Requirement already satisfied: pydub in /usr/local/lib/python3.12/dist-packages (0.25.1)
# Requirement already satisfied: datasets in /usr/local/lib/python3.12/dist-packages (4.0.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from datasets) (3.19.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from datasets) (2.0.2)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.12/dist-packages (from datasets) (18.1.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.12/dist-packages (from datasets) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from datasets) (2.2.2)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.12/dist-packages (from datasets) (2.32.4)
# Requirement already satisfied: tqdm>=4.66.3 in /usr/local/lib/python3.12/dist-packages (from datasets) (4.67.1)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.12/dist-packages (from datasets) (3.5.0)
# Requirement already satisfied: multiprocess<0.70.17 in /usr/local/lib/python3.12/dist-packages (from datasets) (0.70.16)
# Requirement already satisfied: fsspec<=2025.3.0,>=2023.1.0 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (2025.3.0)
# Requirement already satisfied: huggingface-hub>=0.24.0 in /usr/local/lib/python3.12/dist-packages (from datasets) (0.34.4)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from datasets) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from datasets) (6.0.2)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (3.12.15)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.24.0->datasets) (4.15.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.24.0->datasets) (1.1.9)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets) (2025.8.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (6.6.4)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (0.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.20.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.17.0)

# %%
import zipfile
import os

# Replace with your uploaded ZIP file path
zip_path = '/content/drive/MyDrive/Collab/TTS/data.zip'  # or use the actual uploaded filename
extract_to = '/content'  # change as needed

# Create extract directory if it doesn't exist
os.makedirs(extract_to, exist_ok=True)

# Extract the zip
with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(extract_to)

print(f"Extracted to: {extract_to}")
# Out:
# Extracted to: /content

# %% [markdown]
# SENTENCE-LEVEL ALLIGN

# %%
import torch
from ctc_forced_aligner import (
    load_audio,
    load_alignment_model,
    generate_emissions,
    preprocess_text,
    get_alignments,
    get_spans,
    postprocess_results,
)
from pydub import AudioSegment
import os
import re
import csv

# Input folders
audio_folder = "/content/wav"
text_folder = "/content/txt"
output_root = "/content/splits/"

language = "nzi"  # ISO-639-3 Language code
device = "cuda" if torch.cuda.is_available() else "cpu"
batch_size = 16

# Create output structure
os.makedirs(output_root, exist_ok=True)
wav_output_folder = os.path.join(output_root, "wav")
os.makedirs(wav_output_folder, exist_ok=True)

# Prepare metadata CSV
metadata_file = os.path.join(output_root, "metadata.csv")
metadata_rows = []

# Load alignment model and tokenizer once
alignment_model, alignment_tokenizer = load_alignment_model(
    device,
    dtype=torch.float16 if device == "cuda" else torch.float32,
)

def split_text_by_sentences(text):
    """
    Split text into sentences based on sentence-ending punctuation marks (., !, ?)
    Returns list of sentences with their character positions
    """
    sentence_endings = ['.', '!', '?']
    sentences = []
    current_sentence = ""
    start_pos = 0

    for i, char in enumerate(text):
        current_sentence += char

        if char in sentence_endings:
            # Clean up the sentence
            clean_sentence = current_sentence.strip()
            if clean_sentence:
                sentences.append({
                    'text': clean_sentence,
                    'start_char': start_pos,
                    'end_char': i + 1,
                    'is_sentence_end': True  # Always true since we're only splitting at sentence ends
                })

            # Start new sentence
            current_sentence = ""
            start_pos = i + 1

    # Handle remaining text if no punctuation at end
    if current_sentence.strip():
        sentences.append({
            'text': current_sentence.strip(),
            'start_char': start_pos,
            'end_char': len(text),
            'is_sentence_end': True
        })

    return sentences

def group_words_by_text_segments(word_timestamps, text_segments):
    """
    Group word timestamps according to pre-defined text segments
    """
    grouped_segments = []

    for seg_idx, text_segment in enumerate(text_segments):
        segment_words = []
        segment_text = text_segment['text']

        # Find words that belong to this text segment
        # We'll match by checking if words appear in the expected order within the segment
        segment_words_list = segment_text.split()
        word_idx_in_segment = 0

        for word_info in word_timestamps:
            if word_idx_in_segment >= len(segment_words_list):
                break

            word = word_info['text'].strip()
            expected_word = segment_words_list[word_idx_in_segment]

            # Simple matching - you might need to improve this based on your data
            if (word.lower() == expected_word.lower() or
                word.lower() in expected_word.lower() or
                expected_word.lower() in word.lower()):
                segment_words.append(word_info)
                word_idx_in_segment += 1

                # If we've found all words for this segment, break
                if word_idx_in_segment >= len(segment_words_list):
                    break

        if segment_words:
            # Calculate start and end times for the group
            group_start = segment_words[0]['start']
            group_end = segment_words[-1]['end']

            # Clean up the text for filename
            clean_text = re.sub(r'[^\w\s-]', '', segment_text)  # Remove punctuation
            clean_text = re.sub(r'\s+', '_', clean_text)  # Replace spaces with underscores
            clean_text = clean_text[:50]  # Limit length for filename

            grouped_segments.append({
                'start': group_start,
                'end': group_end,
                'text': clean_text,
                'word_count': len(segment_words),
                'original_text': segment_text,
                'is_sentence_end': text_segment['is_sentence_end']
            })

            # Remove processed words from the list
            for processed_word in segment_words:
                if processed_word in word_timestamps:
                    word_timestamps.remove(processed_word)

    return grouped_segments

def simple_word_grouping(word_timestamps, words_per_group=5):
    """
    Fallback method: simply group words by a fixed number
    """
    grouped_segments = []

    for i in range(0, len(word_timestamps), words_per_group):
        group = word_timestamps[i:i + words_per_group]

        if group:
            group_start = group[0]['start']
            group_end = group[-1]['end']

            # Create text from all words in group
            group_text = '_'.join([word['text'].strip() for word in group])
            group_text = re.sub(r'[^\w\s-]', '', group_text)[:50]

            original_text = ' '.join([word['text'].strip() for word in group])

            grouped_segments.append({
                'start': group_start,
                'end': group_end,
                'text': group_text,
                'word_count': len(group),
                'original_text': original_text,
                'is_sentence_end': False
            })

    return grouped_segments

# Global counter for unique filenames
global_segment_counter = 1

# Iterate over all wav files
for audio_filename in os.listdir(audio_folder):
    if not audio_filename.lower().endswith(".wav"):
        continue

    base_name = os.path.splitext(audio_filename)[0]

    audio_path = os.path.join(audio_folder, audio_filename)
    text_path = os.path.join(text_folder, base_name + ".txt")

    if not os.path.isfile(text_path):
        print(f"Warning: Text file not found for {audio_filename}, skipping...")
        continue

    print(f"Processing pair: {audio_filename} + {base_name}.txt")

    # Load audio waveform
    audio_waveform = load_audio(audio_path, alignment_model.dtype, alignment_model.device)

    # Read and preprocess text
    with open(text_path, "r", encoding="utf-8") as f:
        lines = f.readlines()
    original_text = "".join(line for line in lines).replace("\n", " ").strip()
    text = original_text

    print(f"Original text: {original_text[:100]}...")

    # Generate emissions (model output probabilities)
    emissions, stride = generate_emissions(
        alignment_model, audio_waveform, batch_size=batch_size
    )

    # Preprocess text
    tokens_starred, text_starred = preprocess_text(
        text,
        romanize=True,
        language=language,
    )

    # Get alignments between audio and text tokens
    segments, scores, blank_token = get_alignments(
        emissions,
        tokens_starred,
        alignment_tokenizer,
    )

    # Get spans (start/end indices) for each token
    spans = get_spans(tokens_starred, segments, blank_token)

    # Postprocess to get word-level timestamps
    word_timestamps = postprocess_results(text_starred, spans, stride, scores)

    print(f"Found {len(word_timestamps)} words")

    # Split text into sentences only
    text_segments = split_text_by_sentences(original_text)
    print(f"Text segments (sentences): {len(text_segments)}")

    if len(text_segments) > 1:
        # Use sentence-based grouping
        grouped_segments = group_words_by_text_segments(word_timestamps.copy(), text_segments)
        print(f"Grouped into {len(grouped_segments)} sentence segments")
    else:
        # Fallback to simple grouping
        print("No sentence endings found, using simple word grouping (5 words per segment)")
        grouped_segments = simple_word_grouping(word_timestamps, words_per_group=5)

    # Load original audio for splitting
    audio = AudioSegment.from_wav(audio_path)

    # Save each segment as separate audio file and add to metadata
    saved_count = 0
    for i, segment_info in enumerate(grouped_segments):
        start_ms = int(segment_info['start'] * 1000)
        end_ms = int(segment_info['end'] * 1000)

        # Check segment duration - skip if longer than 2 minutes (300 seconds)
        segment_duration = (end_ms - start_ms) / 1000
        if segment_duration > 700:
            print(f"Skipping segment {i+1}: Too long ({segment_duration:.1f}s > 300s)")
            continue

        segment_audio = audio[start_ms:end_ms]

        # Create unique filename using global counter
        segment_filename = f"segment_{global_segment_counter:06d}.wav"
        audio_file = os.path.join(wav_output_folder, segment_filename)

        # Export audio segment
        segment_audio.export(audio_file, format="wav")

        # Add to metadata
        metadata_rows.append({
            'filename': segment_filename,
            'text': segment_info['original_text']
        })

        saved_count += 1
        global_segment_counter += 1

        print(f"Saved segment {saved_count}: '{segment_info['original_text'][:50]}...' "
              f"[{segment_info['start']:.2f}s - {segment_info['end']:.2f}s] "
              f"({segment_duration:.1f}s, {segment_info['word_count']} words) -> {segment_filename}")

    print(f"✓ Completed {base_name}: Created {saved_count} segments (skipped {len(grouped_segments) - saved_count} segments > 2min)")
    print("-" * 50)

# Write metadata to CSV with pipe separator
print(f"Writing metadata to {metadata_file}...")
with open(metadata_file, 'w', newline='', encoding='utf-8') as csvfile:
    if metadata_rows:
        fieldnames = metadata_rows[0].keys()
        writer = csv.DictWriter(csvfile, fieldnames=fieldnames, delimiter='|')

        writer.writeheader()
        writer.writerows(metadata_rows)

print(f"All done! Created {len(metadata_rows)} audio segments in {wav_output_folder}")
print(f"Metadata saved to {metadata_file} with {len(metadata_rows)} entries")
# Out:
# /usr/local/lib/python3.12/dist-packages/pydub/utils.py:300: SyntaxWarning: invalid escape sequence '\('
#   m = re.match('([su]([0-9]{1,2})p?) \(([0-9]{1,2}) bit\)$', token)
# /usr/local/lib/python3.12/dist-packages/pydub/utils.py:301: SyntaxWarning: invalid escape sequence '\('
#   m2 = re.match('([su]([0-9]{1,2})p?)( \(default\))?$', token)
# /usr/local/lib/python3.12/dist-packages/pydub/utils.py:310: SyntaxWarning: invalid escape sequence '\('
#   elif re.match('(flt)p?( \(default\))?$', token):
# /usr/local/lib/python3.12/dist-packages/pydub/utils.py:314: SyntaxWarning: invalid escape sequence '\('
#   elif re.match('(dbl)p?( \(default\))?$', token):
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json: 0.00B [00:00, ?B/s]
# `torch_dtype` is deprecated! Use `dtype` instead!
# model.safetensors:   0%|          | 0.00/1.26G [00:00<?, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# vocab.json:   0%|          | 0.00/286 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/74.0 [00:00<?, ?B/s]
# Processing pair: MAT.20.wav + MAT.20.txt
# /usr/local/lib/python3.12/dist-packages/torchaudio/_backend/utils.py:213: UserWarning: In 2.9, this function's implementation will be changed to use torchaudio.load_with_torchcodec` under the hood. Some parameters like ``normalize``, ``format``, ``buffer_size``, and ``backend`` will be ignored. We recommend that you port your code to rely directly on TorchCodec's decoder instead: https://docs.pytorch.org/torchcodec/stable/generated/torchcodec.decoders.AudioDecoder.html#torchcodec.decoders.AudioDecoder.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torchaudio/_backend/ffmpeg.py:88: UserWarning: torio.io._streaming_media_decoder.StreamingMediaDecoder has been deprecated. This deprecation is part of a large refactoring effort to transition TorchAudio into a maintenance phase. The decoding and encoding capabilities of PyTorch for both audio and video are being consolidated into TorchCodec. Please see https://github.com/pytorch/audio/issues/3902 for more information. It will be removed from the 2.9 release.
#   s = torchaudio.io.StreamReader(src, format, None, buffer_size)
# Original text: MAT 20. Gyimayɛvoma mɔɔ wɔ vanye egyinli ne anu la. Gyisɛse vale zɔle zolɛ kɛ, Kɛ Anwuma Belemgbunli...
# Found 817 words
# Text segments (sentences): 48
# Grouped into 48 sentence segments
# Saved segment 1: 'MAT 20....' [0.72s - 0.90s] (0.2s, 2 words) -> segment_000001.wav
# Saved segment 2: 'Gyimayɛvoma mɔɔ wɔ vanye egyinli ne anu la....' [0.94s - 2.60s] (1.7s, 8 words) -> segment_000002.wav
# Saved segment 3: 'Gyisɛse vale zɔle zolɛ kɛ, Kɛ Anwuma Belemgbunlili...' [4.36s - 14.84s] (10.5s, 32 words) -> segment_000003.wav
# Saved segment 4: 'Ɔ nee bɛ lile ɔ nloa kɛ kenle ko ɔkɛdua bɛ etaku n...' [15.82s - 21.22s] (5.4s, 20 words) -> segment_000004.wav
# Saved segment 5: 'Ɔvindele bieko kɛyɛ dɔne ngɔnla mekɛ ne anu na ɔhɔ...' [21.92s - 28.64s] (6.7s, 21 words) -> segment_000005.wav
# Saved segment 6: 'Na ɔzele bɛ kɛ, Bɛdabɛ noko bɛhɔ me vanye egyinli ...' [29.54s - 36.72s] (7.2s, 21 words) -> segment_000006.wav
# Saved segment 7: 'Na bɛhɔle....' [37.44s - 37.94s] (0.5s, 2 words) -> segment_000007.wav
# Saved segment 8: 'Eza bɛbɔle dɔne bulu nee nwiɔ nee dɔne nsa la ɔvin...' [38.48s - 43.74s] (5.3s, 15 words) -> segment_000008.wav
# Saved segment 9: 'Mɔɔ ɔka ekyii bɛbɔ dɔne nnu la ɔvindele bieko ɔhɔl...' [44.62s - 51.02s] (6.4s, 21 words) -> segment_000009.wav
# Saved segment 10: 'Ɔbizale bɛ kɛ, Duzu ati a aleɛ bedevinli ye mɔɔ ɛh...' [51.50s - 56.36s] (4.9s, 18 words) -> segment_000010.wav
# Saved segment 11: 'Bɛbuale ye kɛ, Ɔboalekɛ awie biala ɛtɛbɔle yɛ ɛkpa...' [57.40s - 60.70s] (3.3s, 9 words) -> segment_000011.wav
# Saved segment 12: 'Na ɔzele bɛ kɛ, Ɛnee bɛdabɛ noko bɛhɔyɛ gyima wɔ m...' [61.26s - 66.08s] (4.8s, 15 words) -> segment_000012.wav
# Saved segment 13: 'Mɔɔ aleɛ ne yɛle nɔsolɛ la, egyinli menle ne zele ...' [66.96s - 78.34s] (11.4s, 34 words) -> segment_000013.wav
# Saved segment 14: 'Yemɔti bɛdabɛ mɔɔ bɛbɔle gyima ne abo dɔne nnu la ...' [79.24s - 84.12s] (4.9s, 15 words) -> segment_000014.wav
# Saved segment 15: 'Mɔɔ alumuama rale la, bɛdwenlenle kɛ bɛkɛnyia ahat...' [84.70s - 91.14s] (6.4s, 15 words) -> segment_000015.wav
# Saved segment 16: 'Bɛduale bɛ kakɛ bɛwiele la, bɛdendɛle bɛ nzo abo b...' [92.04s - 106.64s] (14.6s, 41 words) -> segment_000016.wav
# Saved segment 17: 'Na egyinli menle ne buale bɛ nuhua ko kɛ, Ayi, met...' [107.50s - 114.34s] (6.8s, 21 words) -> segment_000017.wav
# Saved segment 18: 'Wɔmɔ die wɔ ahatualɛ ne na kɔ sua nu....' [114.92s - 117.16s] (2.2s, 9 words) -> segment_000018.wav
# Saved segment 19: 'Mekola metua amozi amra kakɛ ko ne ala, kɛmɔ mendu...' [117.66s - 121.44s] (3.8s, 12 words) -> segment_000019.wav
# Saved segment 20: 'Ɛkpondɛ wɔaze kɛ menlɛ adenle kɛ mefa me ezukoa me...' [122.30s - 126.56s] (4.3s, 15 words) -> segment_000020.wav
# Saved segment 21: 'Anzɛɛ ɔyɛ wɔ anyebolo kɛ me ti akunlu le kpalɛ la ...' [127.28s - 130.24s] (3.0s, 12 words) -> segment_000021.wav
# Saved segment 22: '....' [130.26s - 130.32s] (0.1s, 1 words) -> segment_000022.wav
# Saved segment 23: 'Na Gyisɛse dwulale ye edwɛkɛ ne zɛhae, Yemɔti amoz...' [131.26s - 137.78s] (6.5s, 15 words) -> segment_000023.wav
# Saved segment 24: 'Gyisɛse ka ye ewule nwo edwɛkɛ mɔɔ tɔ zo nsa....' [137.94s - 139.98s] (2.0s, 10 words) -> segment_000024.wav
# Saved segment 25: 'Gyisɛse kɔ Gyɛlusalɛm la, ɔvɛlɛle ye ɛdoavolɛma ne...' [140.02s - 150.44s] (10.4s, 23 words) -> segment_000025.wav
# Saved segment 26: 'Ɛkɛ ne, bɛbaye medame Sonla Ra bɛamaa sɛlɛvolɛ mgb...' [150.96s - 156.92s] (6.0s, 14 words) -> segment_000026.wav
# Saved segment 27: 'Bɛbabua me ewule fɔlɛ, na bɛava me bɛawula menli m...' [157.80s - 162.50s] (4.7s, 15 words) -> segment_000027.wav
# Saved segment 28: 'Bɛdabɛ noko bɛbazi me amgbu, bɛabila me empele, na...' [163.14s - 172.12s] (9.0s, 26 words) -> segment_000028.wav
# Saved segment 29: 'Ninli ɛbizalɛdeɛ....' [172.16s - 173.40s] (1.2s, 2 words) -> segment_000029.wav
# Saved segment 30: 'Akee Zɛbɛdi aye ne nee ɔ mra mrenya nwiɔ ne rale G...' [173.44s - 180.80s] (7.4s, 23 words) -> segment_000030.wav
# Saved segment 31: 'Gyisɛse bizale ye kɛ, Duzu a ɛkpondɛ a....' [181.30s - 184.14s] (2.8s, 8 words) -> segment_000031.wav
# Saved segment 32: 'Ɔbuale kɛ, Bɔ me ɛwɔkɛ kɛ saa ɛdi wɔ belemgbunli n...' [185.06s - 194.96s] (9.9s, 29 words) -> segment_000032.wav
# Saved segment 33: 'Gyisɛse buale kɛ, Bɛnze mɔɔ bɛlɛbiza bɛalie la....' [196.14s - 199.48s] (3.3s, 8 words) -> segment_000033.wav
# Saved segment 34: 'Asoo amaneɛnwunlɛ dwora ne mɔɔ mebanlo nu la, bɛkɛ...' [200.18s - 204.00s] (3.8s, 11 words) -> segment_000034.wav
# Saved segment 35: 'Bɛbuale kɛ, Yɛkɛhola....' [204.90s - 206.94s] (2.0s, 3 words) -> segment_000035.wav
# Saved segment 36: 'Gyisɛse zele bɛ kɛ, Nɔhalɛ, bɛkɛhola bɛkɛnlo amane...' [207.84s - 225.20s] (17.4s, 45 words) -> segment_000036.wav
# Saved segment 37: 'Mɔɔ ɛdoavolɛma bulu ne mɔɔ ɛha la dele ɛhye la, bɛ...' [226.14s - 230.66s] (4.5s, 12 words) -> segment_000037.wav
# Saved segment 38: 'Yemɔti Gyisɛse vɛlɛle bɛ muala wɔ ɔ nwo ɛkɛ na ɔze...' [231.10s - 242.92s] (11.8s, 35 words) -> segment_000038.wav
# Saved segment 39: 'Na bɛmɛ, ɛhye ɛmbɔnle bɛ nwo....' [243.44s - 245.62s] (2.2s, 6 words) -> segment_000039.wav
# Saved segment 40: 'Saa bɛ nuhua bie kpondɛ kɛ ɔyɛ kpole wɔ bɛ nu a, ɛ...' [246.52s - 265.84s] (19.3s, 55 words) -> segment_000040.wav
# Saved segment 41: 'Gyisɛse yɛ anyenzinliravolɛma nwiɔ ayile....' [266.10s - 268.20s] (2.1s, 5 words) -> segment_000041.wav
# Saved segment 42: 'Mɔɔ bɛvi Gyɛleko bɛkɔ la, menli dɔɔnwo kpalɛ doale...' [268.26s - 272.18s] (3.9s, 10 words) -> segment_000042.wav
# Saved segment 43: 'Anyenzinliravolɛma nwiɔ mɔɔ ɛnee dede adehane ne l...' [273.00s - 286.64s] (13.6s, 26 words) -> segment_000043.wav
# Saved segment 44: 'Menli ne dendɛle bɛ na bɛzele bɛ kɛ bɛyɛ koonwu....' [287.90s - 291.36s] (3.5s, 10 words) -> segment_000044.wav
# Saved segment 45: 'Noko anyenzinliravolɛma ne deɛdeanle nuhua kpalɛ k...' [292.16s - 299.00s] (6.8s, 12 words) -> segment_000045.wav
# Saved segment 46: 'Gyisɛse gyinlanle, ɔvɛlɛle bɛ na ɔbizale bɛ kɛ, Du...' [300.10s - 305.70s] (5.6s, 16 words) -> segment_000046.wav
# Saved segment 47: 'Bɛbuale kɛ, Yɛmenle, yɛkulo kɛ ɛbuke yɛ nye ɛmaa y...' [306.64s - 313.68s] (7.0s, 11 words) -> segment_000047.wav
# Saved segment 48: 'Gyisɛse nwunle bɛ anwunvɔne na ɔvale ɔ sa ɔhehanle...' [314.80s - 326.28s] (11.5s, 28 words) -> segment_000048.wav
# ✓ Completed MAT.20: Created 48 segments (skipped 0 segments > 2min)
# --------------------------------------------------
# Processing pair: MAT.21.wav + MAT.21.txt
# Original text: MAT 21. Gyisɛse kɔ Gyɛlusalɛm konimlilɛ nu. Mɔɔ Gyisɛse nee ye ɛdoavolɛma ne bikyele Gyɛlusalɛm na b...
# Found 1237 words
# Text segments (sentences): 88
# Grouped into 88 sentence segments
# Saved segment 1: 'MAT 21....' [0.68s - 0.94s] (0.3s, 2 words) -> segment_000049.wav
# Saved segment 2: 'Gyisɛse kɔ Gyɛlusalɛm konimlilɛ nu....' [1.00s - 2.76s] (1.8s, 5 words) -> segment_000050.wav
# Saved segment 3: 'Mɔɔ Gyisɛse nee ye ɛdoavolɛma ne bikyele Gyɛlusalɛ...' [4.64s - 24.66s] (20.0s, 51 words) -> segment_000051.wav
# Saved segment 4: 'Bɛzianyi bɛ na bɛva bɛ bɛrɛlɛ me....' [25.34s - 27.30s] (2.0s, 7 words) -> segment_000052.wav
# Saved segment 5: 'Na saa awie biala biza bɛ nwolɛ edwɛkɛ a bɛze ye k...' [28.16s - 33.94s] (5.8s, 21 words) -> segment_000053.wav
# Saved segment 6: 'Ɛhye zile amaa mɔɔ Nyamenle kpɔmanvolɛ ne hanle la...' [34.78s - 38.86s] (4.1s, 12 words) -> segment_000054.wav
# Saved segment 7: 'Ka kile suakpole Zayɔn kɛ....' [39.74s - 41.36s] (1.6s, 5 words) -> segment_000055.wav
# Saved segment 8: 'Nea, wɔ belemgbunli ne ɛlɛba ɛ nwo....' [42.06s - 44.50s] (2.4s, 7 words) -> segment_000056.wav
# Saved segment 9: 'Ɔle bɛlɛvo na ɔde asoaso nee asoaso ralɛ zo....' [45.32s - 48.80s] (3.5s, 9 words) -> segment_000057.wav
# Saved segment 10: 'Ɛdoavolɛma ne hɔle na bɛhɔyɛle ye kɛmɔ Gyisɛse han...' [49.68s - 53.72s] (4.0s, 12 words) -> segment_000058.wav
# Saved segment 11: 'Bɛvale asoaso ne nee ɔ ra ne bɛrale na bɛvale bɛ n...' [54.32s - 62.52s] (8.2s, 18 words) -> segment_000059.wav
# Saved segment 12: 'Menli dɔɔnwo kpalɛ noko sesɛle bɛ ndanlɛ wɔ adenle...' [63.46s - 72.32s] (8.9s, 21 words) -> segment_000060.wav
# Saved segment 13: 'Na menli dɔɔnwo ne mɔɔ li ɔ nyunlu nee ɔ nzi la de...' [73.06s - 79.46s] (6.4s, 20 words) -> segment_000061.wav
# Saved segment 14: 'Nyamenle ɛyila mɔɔ lua Awulae duma nu ɛlɛba la!...' [79.90s - 82.76s] (2.9s, 9 words) -> segment_000062.wav
# Saved segment 15: 'Bɛye Nyamenle ayɛlɛ....' [83.22s - 84.30s] (1.1s, 3 words) -> segment_000063.wav
# Saved segment 16: 'Mɔɔ Gyisɛse dwule Gyɛlusalɛm la, suakpole ne azo k...' [85.26s - 92.26s] (7.0s, 15 words) -> segment_000064.wav
# Saved segment 17: 'Na menli dɔɔnwo ne zele kɛ, Ɛhye a le Nyamenle kpɔ...' [93.28s - 102.84s] (9.6s, 23 words) -> segment_000065.wav
# Saved segment 18: 'Gyisɛse kɔ Ɛzonlenlɛ Sua ne anu....' [102.88s - 105.02s] (2.1s, 6 words) -> segment_000066.wav
# Saved segment 19: 'Gyisɛse hɔle Ɛzonlenlɛ Sua ne anu na ɔvoanle bɛdab...' [105.06s - 110.22s] (5.2s, 17 words) -> segment_000067.wav
# Saved segment 20: 'Ɔbutubutule menli mɔɔ senza ezukoa la ɛkponle ne m...' [110.80s - 127.74s] (16.9s, 40 words) -> segment_000068.wav
# Saved segment 21: 'Na bɛmɛ, bɛyɛ ye awulema fealeka....' [128.18s - 130.12s] (1.9s, 6 words) -> segment_000069.wav
# Saved segment 22: 'Anyenzinliravolɛma nee abuburama rale ɔ nwo ɛkɛ ne...' [131.04s - 137.80s] (6.8s, 17 words) -> segment_000070.wav
# Saved segment 23: 'Mɔɔ sɛlɛvolɛ mgbanyinli ne nee mɛla kilehilevolɛma...' [138.70s - 154.26s] (15.6s, 34 words) -> segment_000071.wav
# Saved segment 24: 'la, bɛvale ɛya....' [155.36s - 156.54s] (1.2s, 3 words) -> segment_000072.wav
# Saved segment 25: 'Yemɔti bɛbizale Gyisɛse kɛ, Ɛte mɔɔ ɛhye mɔ ɛlɛkeh...' [157.34s - 161.44s] (4.1s, 11 words) -> segment_000073.wav
# Saved segment 26: 'Gyisɛse buale bɛ kɛ, Nɔhalɛ, mete....' [162.46s - 165.10s] (2.6s, 6 words) -> segment_000074.wav
# Saved segment 27: 'Na bɛtɛkengale Nyamenle Edwɛkɛ ne mɔɔ fane ɛhye an...' [165.60s - 168.72s] (3.1s, 11 words) -> segment_000075.wav
# Saved segment 28: 'Ɔse....' [169.24s - 169.44s] (0.2s, 1 words) -> segment_000076.wav
# Saved segment 29: 'Bɛtete ngakula ndetendete nee nlɔma kɛ....' [169.98s - 172.60s] (2.6s, 6 words) -> segment_000077.wav
# Saved segment 30: 'bɛye Nyamenle ayɛlɛ mɔɔ di munli a!...' [172.90s - 174.66s] (1.8s, 7 words) -> segment_000078.wav
# Saved segment 31: '....' [174.68s - 175.08s] (0.4s, 1 words) -> segment_000079.wav
# Saved segment 32: 'Na Gyisɛse gyakyile bɛ ɛkɛ ne na ɔvile Gyɛlusalɛm ...' [175.70s - 181.14s] (5.4s, 12 words) -> segment_000080.wav
# Saved segment 33: 'Gyisɛse wa feege baka ne amonle....' [181.18s - 183.48s] (2.3s, 6 words) -> segment_000081.wav
# Saved segment 34: 'Aleɛ hyenle nwonlomɔ mangyee ne na Gyisɛse sia ahɔ...' [183.52s - 190.46s] (6.9s, 18 words) -> segment_000082.wav
# Saved segment 35: 'Ɔnwunle feege baka bie kɛ ɔgyi adehane ne, ɔhɔle ɔ...' [191.12s - 200.62s] (9.5s, 24 words) -> segment_000083.wav
# Saved segment 36: 'Yemɔti ɔzele baka ne kɛ, Ɛnrɛzo ma bieko ɛlɛ!...' [201.10s - 204.86s] (3.8s, 9 words) -> segment_000084.wav
# Saved segment 37: 'Na ɛkɛ ne ala feege baka ne nwosonle....' [205.92s - 208.40s] (2.5s, 8 words) -> segment_000085.wav
# Saved segment 38: 'Ɛhye zinle ɛdoavolɛma ne anwo kpole na bɛbizale Gy...' [209.14s - 217.00s] (7.9s, 20 words) -> segment_000086.wav
# Saved segment 39: 'Gyisɛse buale kɛ, Bɛhakye ɛhye!...' [218.12s - 220.88s] (2.8s, 5 words) -> segment_000087.wav
# Saved segment 40: 'Saa bɛdie bɛdi na bɛanzu kpolera a, bɛkɛhola bɛkɛy...' [221.54s - 226.90s] (5.4s, 16 words) -> segment_000088.wav
# Saved segment 41: 'Bɔbɔ bɛkɛhola bɛkɛze boka ɛhye kɛ, Tudu kɔdɔ nyevi...' [227.54s - 232.52s] (5.0s, 13 words) -> segment_000089.wav
# Saved segment 42: 'Saa bɛdie bɛdi a, bɛ sa kɛha debie biala mɔɔ bɛkɛb...' [233.16s - 237.20s] (4.0s, 15 words) -> segment_000090.wav
# Saved segment 43: 'Gyisɛse tumi ne anwo edwɛkɛ....' [237.38s - 239.70s] (2.3s, 5 words) -> segment_000091.wav
# Saved segment 44: 'Gyisɛse ziale rale Ɛzonlenlɛ Sua ne anu, na mɔɔ ɔl...' [239.74s - 251.42s] (11.7s, 35 words) -> segment_000092.wav
# Saved segment 45: 'Nwane a manle wɔ tumi ɛhye a....' [251.88s - 253.22s] (1.3s, 7 words) -> segment_000093.wav
# Saved segment 46: 'Gyisɛse buale bɛ kɛ, Medame noko mebiza bɛ kpuyia ...' [254.24s - 263.20s] (9.0s, 28 words) -> segment_000094.wav
# Saved segment 47: 'Tumi ne mɔɔ Dwɔn nyianle ye vale zɔnenle menli la ...' [263.74s - 269.62s] (5.9s, 17 words) -> segment_000095.wav
# Saved segment 48: 'Na bɛbɔle ɔ bo kɛ bɛsu bɛ nwo kpolera kɛ, Duzu edw...' [270.54s - 274.74s] (4.2s, 15 words) -> segment_000096.wav
# Saved segment 49: 'Saa yɛbua kɛ, Ɔvi Nyamenle a, ɔkɛbiza yɛ kɛ, Ɛnee ...' [275.18s - 280.36s] (5.2s, 16 words) -> segment_000097.wav
# Saved segment 50: 'Saa yɛka noko kɛ, Ɔvi sonla a, yɛsulo menli ye, ɔb...' [281.38s - 288.96s] (7.6s, 21 words) -> segment_000098.wav
# Saved segment 51: 'Yemɔti bɛbuale Gyisɛse kɛ, Yɛnze....' [289.82s - 292.44s] (2.6s, 5 words) -> segment_000099.wav
# Saved segment 52: 'Na Gyisɛse ɔdaye ɔzele bɛ kɛ, Ɛnee medame noko men...' [293.44s - 301.58s] (8.1s, 25 words) -> segment_000100.wav
# Saved segment 53: 'Mralɛ mrenya nwiɔ ne anwo ɛrɛlɛ....' [301.68s - 302.50s] (0.8s, 6 words) -> segment_000101.wav
# Saved segment 54: 'Akee Gyisɛse bizale bɛ edwɛkɛ ɛhye, ɔse, Kɛ bɛdwen...' [302.54s - 307.28s] (4.7s, 13 words) -> segment_000102.wav
# Saved segment 55: 'Nrenya bie lɛ ɔ mra mrenya nwiɔ....' [307.86s - 309.36s] (1.5s, 7 words) -> segment_000103.wav
# Saved segment 56: 'Ɔhɔle mɔɔ lumua la anwo ɛkɛ ne ɔhɔzele ye kɛ, Me r...' [310.12s - 316.70s] (6.6s, 21 words) -> segment_000104.wav
# Saved segment 57: 'Na ɔbuale ye kɛ, Menrɛhɔ, Noko nzinlii ɔnlunle ɔ n...' [317.52s - 321.28s] (3.8s, 12 words) -> segment_000105.wav
# Saved segment 58: 'Ɔhɔle ko ne noko ɛkɛ ne na ɔhɔhanle edwɛkɛ ko ne a...' [322.08s - 325.58s] (3.5s, 14 words) -> segment_000106.wav
# Saved segment 59: 'Na ɔbuale kɛ, Egya, mebahɔ....' [326.28s - 328.36s] (2.1s, 5 words) -> segment_000107.wav
# Saved segment 60: 'Noko yeangɔ....' [328.76s - 329.22s] (0.5s, 2 words) -> segment_000108.wav
# Saved segment 61: 'Ɛnee ngakula nwiɔ ɛhye, bɛ nuhua boni a yɛle ɔ ze ...' [330.08s - 333.40s] (3.3s, 13 words) -> segment_000109.wav
# Saved segment 62: 'Bɛzele ye kɛ, Mɔɔ lumua la ɔ....' [334.44s - 336.94s] (2.5s, 7 words) -> segment_000110.wav
# Saved segment 63: 'Gyisɛse zele bɛ kɛ, Nɔhalɛ, meka meahile bɛ: Adwul...' [337.94s - 346.68s] (8.7s, 18 words) -> segment_000111.wav
# Saved segment 64: 'Ɔluakɛ Dwɔn Sɔnevolɛ ne rale na ɔrahilehilele bɛ n...' [347.64s - 363.46s] (15.8s, 37 words) -> segment_000112.wav
# Saved segment 65: 'Abunsama ne mɔɔ wɔ vanye egyinli ne anu la anwo ɛr...' [363.50s - 364.56s] (1.1s, 11 words) -> segment_000113.wav
# Saved segment 66: 'Eza Gyisɛse zele bɛ kɛ, Bɛdie ɛrɛlɛ ɛhye noko....' [364.60s - 367.78s] (3.2s, 9 words) -> segment_000114.wav
# Saved segment 67: 'Azɛlɛ menle bie yɛle ye vanye egyinli na ɔhyele nw...' [368.50s - 372.06s] (3.6s, 11 words) -> segment_000115.wav
# Saved segment 68: 'Ɔdule kuma mɔɔ bɛbahwihwi vanye ma ne anu nzule bɛ...' [372.64s - 382.68s] (10.0s, 24 words) -> segment_000116.wav
# Saved segment 69: 'Akee ɔvale egyinli ne ɔwulale abunsama asa anu na ...' [383.46s - 389.38s] (5.9s, 15 words) -> segment_000117.wav
# Saved segment 70: 'Ɛbuhenle ne dwule la, ɔzoanle ye sonvolɛma bie mɔ ...' [390.30s - 396.60s] (6.3s, 18 words) -> segment_000118.wav
# Saved segment 71: 'Na abunsama ne hyele sonvolɛma ne, bɛbole ko, bɛhu...' [397.14s - 403.74s] (6.6s, 14 words) -> segment_000119.wav
# Saved segment 72: 'Egyinli menle ne eza zoanle ye sonvolɛma mɔɔ zonle...' [404.66s - 411.70s] (7.0s, 21 words) -> segment_000120.wav
# Saved segment 73: 'Nzinlii ɔzoanle ɔ ra nrenya wɔ bɛ nwo lɔ, na ɔdwen...' [412.42s - 418.32s] (5.9s, 19 words) -> segment_000121.wav
# Saved segment 74: 'Na mɔɔ abunsama ne nwunle ɔ ra ne la, bɛhanle bɛhi...' [419.18s - 424.24s] (5.1s, 18 words) -> segment_000122.wav
# Saved segment 75: 'Bɛrɛla bɛmaa yɛhu ye na yɛva ye agyadeɛ ne!...' [424.78s - 426.80s] (2.0s, 9 words) -> segment_000123.wav
# Saved segment 76: 'Yemɔti bɛhyele ye na bɛvale ye bɛvindele egyinli n...' [427.64s - 432.38s] (4.7s, 13 words) -> segment_000124.wav
# Saved segment 77: 'Na ɛnee bɛnea a saa vanye egyinli ne amenle ba a, ...' [433.14s - 437.82s] (4.7s, 17 words) -> segment_000125.wav
# Saved segment 78: 'Bɛbuale ye kɛ, Ɔkɛhu amumuyɛma ne na ɔkɛva ye egyi...' [438.80s - 448.22s] (9.4s, 29 words) -> segment_000126.wav
# Saved segment 79: 'Gyisɛse zele bɛ kɛ, Asoo bɛtɛkengale Nyamenle Edwɛ...' [449.10s - 453.04s] (3.9s, 10 words) -> segment_000127.wav
# Saved segment 80: 'Ɔse....' [453.48s - 453.68s] (0.2s, 1 words) -> segment_000128.wav
# Saved segment 81: 'Bolɛ ne mɔɔ suasivoma ne kpole la....' [454.46s - 456.28s] (1.8s, 7 words) -> segment_000129.wav
# Saved segment 82: 'ɛrayɛ bolɛ mɔɔ anwo hyia kpole kpalɛ....' [456.82s - 458.98s] (2.2s, 7 words) -> segment_000130.wav
# Saved segment 83: 'kɛ sua mgbɛne zo sika la....' [459.44s - 461.94s] (2.5s, 6 words) -> segment_000131.wav
# Saved segment 84: 'Awulae a yɛle ɛhye a; na ɔyɛ nwanwane kpole....' [462.62s - 465.82s] (3.2s, 9 words) -> segment_000132.wav
# Saved segment 85: 'Zɔhane ati meka meahile bɛ, bɛbalie Nyamenle Belem...' [466.64s - 473.64s] (7.0s, 20 words) -> segment_000133.wav
# Saved segment 86: 'Na awie biala mɔɔ kɛdɔ bolɛ ɛhye azo la kɛtete nzo...' [474.54s - 482.96s] (8.4s, 24 words) -> segment_000134.wav
# Saved segment 87: 'Sɛlɛvolɛ mgbanyinli ne nee Falasiima ne mɔ dele Gy...' [483.98s - 492.70s] (8.7s, 23 words) -> segment_000135.wav
# Saved segment 88: 'Ɛhye ati bɛyɛle kɛ bɛkye ye; noko akee bɛzulole, ɔ...' [493.62s - 504.68s] (11.1s, 21 words) -> segment_000136.wav
# ✓ Completed MAT.21: Created 88 segments (skipped 0 segments > 2min)
# --------------------------------------------------
# Processing pair: MAT.11.wav + MAT.11.txt
# Original text: MAT 11. Menli mɔɔ Dwɔn Sɔnevolɛ ne zoanle bɛ la. Mɔɔ Gyisɛse wiele ye ɛdoavolɛma bulu nee nwiɔ ne fo...
# Found 802 words
# Text segments (sentences): 49
# Grouped into 49 sentence segments
# Saved segment 1: 'MAT 11....' [0.68s - 0.80s] (0.1s, 2 words) -> segment_000137.wav
# Saved segment 2: 'Menli mɔɔ Dwɔn Sɔnevolɛ ne zoanle bɛ la....' [0.84s - 2.20s] (1.4s, 8 words) -> segment_000138.wav
# Saved segment 3: 'Mɔɔ Gyisɛse wiele ye ɛdoavolɛma bulu nee nwiɔ ne f...' [4.18s - 14.96s] (10.8s, 29 words) -> segment_000139.wav
# Saved segment 4: 'Gyisɛse gyima mɔɔ ɛnee ɔlɛdi la nganeɛ dwule Dwɔn ...' [15.88s - 23.48s] (7.6s, 20 words) -> segment_000140.wav
# Saved segment 5: 'Yemɔti ɔzoanle ye ɛdoavolɛma ne bie mɔ wɔ Gyisɛse ...' [24.30s - 36.68s] (12.4s, 35 words) -> segment_000141.wav
# Saved segment 6: 'Gyisɛse buale kɛ, Bɛzia bɛhɔha mɔɔ bɛde nee mɔɔ bɛ...' [37.78s - 57.22s] (19.4s, 37 words) -> segment_000142.wav
# Saved segment 7: 'Nyilalɛ ɛha bɛdabɛ mɔɔ bɛ ti anu ɛnyɛ bɛ kesee wɔ ...' [58.08s - 61.52s] (3.4s, 14 words) -> segment_000143.wav
# Saved segment 8: 'Mɔɔ Dwɔn ɛdoavolɛma ne ziale kɛ bɛkɔ la, Gyisɛse b...' [62.58s - 70.06s] (7.5s, 21 words) -> segment_000144.wav
# Saved segment 9: 'Ɔse, Mɔɔ bɛhɔle Dwɔn anwo lɔ wɔ fienemgbole ne anu...' [70.36s - 75.92s] (5.6s, 21 words) -> segment_000145.wav
# Saved segment 10: 'Ɛhonle mɔɔ anwoma ɛlɛkpusu ye la ɔ?...' [76.54s - 78.82s] (2.3s, 7 words) -> segment_000146.wav
# Saved segment 11: 'Na duzu a bɛhɔle ye ɛnleanlɛ a?...' [79.96s - 81.62s] (1.7s, 7 words) -> segment_000147.wav
# Saved segment 12: 'Awie mɔɔ heda ɛdakpa la ɔ?...' [82.42s - 84.40s] (2.0s, 6 words) -> segment_000148.wav
# Saved segment 13: 'Bɛdabɛ mɔɔ bɛheda ɛdakpa la dede arelemgbunli azua...' [85.10s - 88.54s] (3.4s, 9 words) -> segment_000149.wav
# Saved segment 14: 'Bɛha bɛhile me ɛ; ɛnee akee duzu a bɛhɔle ye ɛnlea...' [89.44s - 93.02s] (3.6s, 12 words) -> segment_000150.wav
# Saved segment 15: 'Nyamenle kpɔmanvolɛ ɔ?...' [93.72s - 94.58s] (0.9s, 3 words) -> segment_000151.wav
# Saved segment 16: 'Ɛhɛe, na meka meahile bɛ kɛ bɛnwunle awie mɔɔ tɛla...' [95.10s - 99.66s] (4.6s, 14 words) -> segment_000152.wav
# Saved segment 17: 'Ɔluakɛ Dwɔn a Nyamenle Edwɛkɛ ne ka ye ɔ nwo kɛ: N...' [100.66s - 112.98s] (12.3s, 28 words) -> segment_000153.wav
# Saved segment 18: 'Nɔhalɛ, meka meahile bɛ, wɔ menli mɔɔ bɛwo bɛ bɛgu...' [113.90s - 123.96s] (10.1s, 26 words) -> segment_000154.wav
# Saved segment 19: 'Noko akee awie mɔɔ le ekyi wɔ Anwuma Belemgbunlili...' [124.54s - 129.62s] (5.1s, 15 words) -> segment_000155.wav
# Saved segment 20: 'Ɔvi mekɛ mɔɔ Dwɔn Sɔnevolɛ ne bɔle ye nolobɔlɛ bo ...' [130.56s - 144.16s] (13.6s, 34 words) -> segment_000156.wav
# Saved segment 21: 'Ɔluakɛ Nyamenle kpɔmanvolɛma ne mɔ amuala nee Mosi...' [145.08s - 161.04s] (16.0s, 40 words) -> segment_000157.wav
# Saved segment 22: 'Mɔɔ lɛ ɛnzonlɛ la ɛdie....' [161.72s - 163.32s] (1.6s, 5 words) -> segment_000158.wav
# Saved segment 23: 'Ɛnee akee duzu a menva adwuleso amra ɛhye mendo nw...' [165.58s - 169.20s] (3.6s, 11 words) -> segment_000159.wav
# Saved segment 24: 'Bɛle kɛ ngakula mɔɔ ɛlɛdi nwɔhoa wɔ gua zo la....' [169.76s - 172.58s] (2.8s, 10 words) -> segment_000160.wav
# Saved segment 25: 'Bɛdede ye ekpunli ekpunli, na ekpunli ko tea nu se...' [173.10s - 181.38s] (8.3s, 20 words) -> segment_000161.wav
# Saved segment 26: 'Yɛdole ɛzɛne edwɛne la, bɛanzu....' [182.14s - 184.34s] (2.2s, 5 words) -> segment_000162.wav
# Saved segment 27: 'Dwɔn Sɔnevolɛ ne rale na ɔhyele ɛhɔne dahuu, ɔhyil...' [185.10s - 192.76s] (7.7s, 16 words) -> segment_000163.wav
# Saved segment 28: 'Medame, Sonla Ra noko mera, na melɛdi meanlo a, aw...' [193.62s - 200.46s] (6.8s, 14 words) -> segment_000164.wav
# Saved segment 29: 'Adidikpoku, nzanli, adwuledievolɛma nee bɛdabɛ mɔɔ...' [200.96s - 206.62s] (5.7s, 11 words) -> segment_000165.wav
# Saved segment 30: 'Noko Nyamenle nrɛlɛbɛ ne amra ne mɔ nyɛleɛ maa bɛn...' [207.08s - 211.26s] (4.2s, 13 words) -> segment_000166.wav
# Saved segment 31: 'Azua mɔɔ ɛnlɛ diedi la....' [211.30s - 212.52s] (1.2s, 5 words) -> segment_000167.wav
# Saved segment 32: 'Akee Gyisɛse bɔle ɔ bo kɛ ɔtea menli mɔɔ wɔ azua m...' [212.62s - 221.32s] (8.7s, 25 words) -> segment_000168.wav
# Saved segment 33: 'Munzule ɛha bɛdabɛ mɔɔ bɛwɔ Koleezen la!...' [222.20s - 224.50s] (2.3s, 7 words) -> segment_000169.wav
# Saved segment 34: 'Munzule ɛha bɛdabɛ mɔɔ bɛwɔ Bɛteseeyeda la!...' [225.16s - 227.26s] (2.1s, 7 words) -> segment_000170.wav
# Saved segment 35: 'Nwanwane gyima mgbole mɔɔ bɛyɛle wɔ bɛ azua ne mɔ ...' [228.06s - 242.84s] (14.8s, 42 words) -> segment_000171.wav
# Saved segment 36: 'Meka meahile bɛ, Ndɛnebualɛ Kenle ne, Nyamenle baz...' [243.68s - 250.66s] (7.0s, 15 words) -> segment_000172.wav
# Saved segment 37: 'Na bɛmɛ mɔɔ bɛwɔ Kapɛnayɛm la, bɛkpondɛ kɛ bɛkɔ Ny...' [251.62s - 256.56s] (4.9s, 14 words) -> segment_000173.wav
# Saved segment 38: 'Kyɛkyɛ!...' [257.18s - 257.44s] (0.3s, 1 words) -> segment_000174.wav
# Saved segment 39: 'Bɛbavuandi bɛ bɛagua ɛbolɔ senle nu....' [257.98s - 260.00s] (2.0s, 6 words) -> segment_000175.wav
# Saved segment 40: 'Nwanwane gyima mɔɔ bɛyɛle wɔ bɛ sua zo la, saa bɛy...' [260.82s - 269.64s] (8.8s, 24 words) -> segment_000176.wav
# Saved segment 41: 'Bɛnwu ye kɛ, Ndɛnebualɛ Kenle ne, Nyamenle baze So...' [270.52s - 276.56s] (6.0s, 14 words) -> segment_000177.wav
# Saved segment 42: 'Bɛrɛla me ɛkɛ bɛralie bɛ ɛnwomenle....' [276.60s - 278.28s] (1.7s, 6 words) -> segment_000178.wav
# Saved segment 43: 'Mekɛ ne anu Gyisɛse zele kɛ, Egya, anwuma nee aze ...' [278.32s - 289.40s] (11.1s, 31 words) -> segment_000179.wav
# Saved segment 44: 'Ɛhɛe, Egya, ɛnee kɛ ɛkpondɛ kɛ ɔba ye la ɛne....' [290.08s - 293.24s] (3.2s, 10 words) -> segment_000180.wav
# Saved segment 45: 'Egya ɛva ninyɛne kɔsɔɔti ɛmaa me....' [294.16s - 296.82s] (2.7s, 6 words) -> segment_000181.wav
# Saved segment 46: 'Awie biala ɛnze Ralɛ ne sonla holɛ kɛ Selɛ ne ala,...' [297.64s - 308.70s] (11.1s, 35 words) -> segment_000182.wav
# Saved segment 47: 'Bɛdabɛ mɔɔ bɛzo ɛnlomboɛ na bɛvɛ la, bɛ muala bɛrɛ...' [309.76s - 315.68s] (5.9s, 17 words) -> segment_000183.wav
# Saved segment 48: 'Bɛva me gyɛnvayile ne bɛdo bɛ kɔme zo na bɛzukoa m...' [316.60s - 327.52s] (10.9s, 29 words) -> segment_000184.wav
# Saved segment 49: 'Ɔluakɛ me gyɛnvayile ne le felafela, yɛɛ bɔlɛ mɔɔ ...' [328.28s - 337.08s] (8.8s, 15 words) -> segment_000185.wav
# ✓ Completed MAT.11: Created 49 segments (skipped 0 segments > 2min)
# --------------------------------------------------
# Processing pair: MAT.19.wav + MAT.19.txt
# Original text: MAT 19. Ewolebɔlɛ nwo ngilehilelɛ. Gyisɛse wiele ɛhye mɔ ka la, ɔvile Galeli na ɔhɔle Dwudiya maanzi...
# Found 757 words
# Text segments (sentences): 39
# Grouped into 39 sentence segments
# Saved segment 1: 'MAT 19....' [0.72s - 1.02s] (0.3s, 2 words) -> segment_000186.wav
# Saved segment 2: 'Ewolebɔlɛ nwo ngilehilelɛ....' [1.08s - 2.78s] (1.7s, 3 words) -> segment_000187.wav
# Saved segment 3: 'Gyisɛse wiele ɛhye mɔ ka la, ɔvile Galeli na ɔhɔle...' [4.52s - 13.06s] (8.5s, 18 words) -> segment_000188.wav
# Saved segment 4: 'Menli dɔɔnwo doale ye wɔ ɛkɛ ne, na ɔyɛle bɛ ayile...' [13.60s - 16.86s] (3.3s, 11 words) -> segment_000189.wav
# Saved segment 5: 'Falasiima bie rale Gyisɛse anwo ɛkɛ radole ye agyi...' [17.48s - 27.34s] (9.9s, 29 words) -> segment_000190.wav
# Saved segment 6: 'Gyisɛse buale kɛ, Bɛtɛkengale Nyamenle Edwɛkɛ ne m...' [28.44s - 42.56s] (14.1s, 45 words) -> segment_000191.wav
# Saved segment 7: 'Yemɔti ɛnee bɛnle nwiɔ bieko na bɛle ko....' [43.58s - 45.66s] (2.1s, 8 words) -> segment_000192.wav
# Saved segment 8: 'Zɔhane ati mɔɔ Nyamenle ɛha ɛbɔ nu la, ɔnle kɛ awi...' [46.26s - 49.98s] (3.7s, 14 words) -> segment_000193.wav
# Saved segment 9: 'Falasiima ne bizale ye kɛ, Ɛnee duzu ati a Mosisi ...' [50.80s - 60.68s] (9.9s, 31 words) -> segment_000194.wav
# Saved segment 10: 'Gyisɛse buale kɛ, Mosisi manle bɛ adenle kɛ bɛbɔ b...' [61.76s - 67.76s] (6.0s, 18 words) -> segment_000195.wav
# Saved segment 11: 'Mɔlebɛbo ne amuala ɛnee ɔnle zɔ....' [68.26s - 69.78s] (1.5s, 6 words) -> segment_000196.wav
# Saved segment 12: 'Zɔhane ati meka meahile bɛ: Nrenya biala mɔɔ kɛbɔ ...' [70.66s - 79.48s] (8.8s, 27 words) -> segment_000197.wav
# Saved segment 13: 'Ye ɛdoavolɛma ne zele ye kɛ, Saa kɛ ɔde wɔ nrenya ...' [80.38s - 88.18s] (7.8s, 25 words) -> segment_000198.wav
# Saved segment 14: 'Gyisɛse buale kɛ, Tɛ menli kɔsɔɔti a kɛlie ngilehi...' [89.12s - 96.92s] (7.8s, 23 words) -> segment_000199.wav
# Saved segment 15: 'Ɔluakɛ ndenle dɔɔnwo wɔ ɛkɛ ne mɔɔ ɔlua zo mrenya ...' [97.84s - 114.84s] (17.0s, 46 words) -> segment_000200.wav
# Saved segment 16: 'Bɛmaa mɔɔ kɛhola ye yɛ la ɛlie ngilehilelɛ ɛhye ɛd...' [115.34s - 118.66s] (3.3s, 11 words) -> segment_000201.wav
# Saved segment 17: 'Gyisɛse yila ngakula....' [118.84s - 119.66s] (0.8s, 3 words) -> segment_000202.wav
# Saved segment 18: 'Menli bie vale ngakula rɛlɛle Gyisɛse kɛ ɔva ɔ sa ...' [119.70s - 128.92s] (9.2s, 26 words) -> segment_000203.wav
# Saved segment 19: 'Na Gyisɛse zele ɛdoavolɛma ne kɛ, Bɛmmasi ngakula ...' [129.68s - 141.40s] (11.7s, 32 words) -> segment_000204.wav
# Saved segment 20: 'Gyisɛse vale ɔ sa guale bɛ nwo zo na ɔhɔle....' [142.34s - 145.08s] (2.7s, 10 words) -> segment_000205.wav
# Saved segment 21: 'Kpavolɛ sukoavolɛ ne....' [145.26s - 147.06s] (1.8s, 3 words) -> segment_000206.wav
# Saved segment 22: 'Kpavolɛ bie rale Gyisɛse ɛkɛ rabizale ye kɛ, Kileh...' [147.10s - 156.16s] (9.1s, 24 words) -> segment_000207.wav
# Saved segment 23: 'Gyisɛse buale ye kɛ, Duzu ati a ɛlɛbiza me edwɛkɛ ...' [156.20s - 160.96s] (4.8s, 17 words) -> segment_000208.wav
# Saved segment 24: 'Sonla kokye ala a le kpalɛ a....' [161.86s - 162.92s] (1.1s, 7 words) -> segment_000209.wav
# Saved segment 25: 'Saa ɛkpondɛ ngoane a ɛnee di mɛla ne mɔ azo....' [163.76s - 166.12s] (2.4s, 10 words) -> segment_000210.wav
# Saved segment 26: 'Kpavolɛ ne bizale ye kɛ, Duzu mɛla zɛhae....' [166.96s - 170.04s] (3.1s, 8 words) -> segment_000211.wav
# Saved segment 27: 'Gyisɛse buale ye kɛ, Mmaku sonla; mmayɛ awuvolɛval...' [170.96s - 182.36s] (11.4s, 29 words) -> segment_000212.wav
# Saved segment 28: 'Kpavolɛ ne buale kɛ, Meli mɛla ɛhye mɔ amuala azo,...' [183.20s - 188.22s] (5.0s, 18 words) -> segment_000213.wav
# Saved segment 29: 'Gyisɛse buale ye kɛ, Saa ɛkpondɛ kɛ ɛdi munli a, ɛ...' [189.30s - 201.50s] (12.2s, 36 words) -> segment_000214.wav
# Saved segment 30: 'Mɔɔ kpavolɛ ne dele ɛhye la alɔbɔlɛ hunle ye na ɔh...' [202.40s - 208.44s] (6.0s, 16 words) -> segment_000215.wav
# Saved segment 31: 'Na Gyisɛse zele ye ɛdoavolɛma ne kɛ, Meka meahile ...' [209.04s - 216.70s] (7.7s, 19 words) -> segment_000216.wav
# Saved segment 32: 'Meka meazi zolɛ bieko, ɔnyɛ se ɔmmaa afunlumu kɛ ɔ...' [217.60s - 225.44s] (7.8s, 21 words) -> segment_000217.wav
# Saved segment 33: 'Mɔɔ ɛdoavolɛma ne dele ɛhye la, ɔzinle bɛ nwo kpol...' [226.40s - 234.24s] (7.8s, 21 words) -> segment_000218.wav
# Saved segment 34: 'Gyisɛse nleanle bɛ koonwu na ɔbuale bɛ kɛ, Ɛhye yɛ...' [235.20s - 242.52s] (7.3s, 22 words) -> segment_000219.wav
# Saved segment 35: 'Pita hanle kɛ, Nea o, kɛ yɛgyakyi debie biala yɛɛ ...' [243.32s - 247.38s] (4.1s, 13 words) -> segment_000220.wav
# Saved segment 36: 'Duzu a yɛbanyia a....' [248.06s - 248.80s] (0.7s, 4 words) -> segment_000221.wav
# Saved segment 37: 'Gyisɛse zele bɛ kɛ, Meka meahile bɛ, saa medame So...' [249.80s - 266.76s] (17.0s, 47 words) -> segment_000222.wav
# Saved segment 38: 'Awie biala mɔɔ ɛgyakyi ye azua, ɔ mediema mrenya n...' [267.80s - 279.12s] (11.3s, 34 words) -> segment_000223.wav
# Saved segment 39: 'Noko akee bɛdabɛ dɔɔnwo mɔɔ kɛkala bɛlumua la bali...' [279.90s - 290.68s] (10.8s, 20 words) -> segment_000224.wav
# ✓ Completed MAT.19: Created 39 segments (skipped 0 segments > 2min)
# --------------------------------------------------
# Processing pair: MAT.14.wav + MAT.14.txt
# Original text: MAT 14. Dwɔn Sɔnevolɛ ne ewule. Mekɛ ne anu ala Hɛlɔdo mɔɔ ɛnee le amɛnlado mɔɔ sie Galeli maanle ne...
# Found 818 words
# Text segments (sentences): 47
# Grouped into 47 sentence segments
# Saved segment 1: 'MAT 14....' [0.70s - 0.98s] (0.3s, 2 words) -> segment_000225.wav
# Saved segment 2: 'Dwɔn Sɔnevolɛ ne ewule....' [1.06s - 2.42s] (1.4s, 4 words) -> segment_000226.wav
# Saved segment 3: 'Mekɛ ne anu ala Hɛlɔdo mɔɔ ɛnee le amɛnlado mɔɔ si...' [4.06s - 21.50s] (17.4s, 44 words) -> segment_000227.wav
# Saved segment 4: 'Na yemɔ a le kɛ, Hɛlɔdo manle bɛhyele Dwɔn, bɛgual...' [22.58s - 27.80s] (5.2s, 16 words) -> segment_000228.wav
# Saved segment 5: 'Ɔ diema Felepe aye Hɛlɔdease ati a ɔyɛle ɛhye a, ɔ...' [28.48s - 40.32s] (11.8s, 24 words) -> segment_000229.wav
# Saved segment 6: 'Yemɔti Hɛlɔdo dwenlenle nwo kɛ ɔku Dwɔn, noko ɛnee...' [41.12s - 49.36s] (8.2s, 20 words) -> segment_000230.wav
# Saved segment 7: 'Kenle ko Hɛlɔdo awolɛ kenle dwule na ɔdi ye ɛvoyia...' [50.20s - 58.90s] (8.7s, 21 words) -> segment_000231.wav
# Saved segment 8: 'Hɛlɔdo anye liele ye agolezilɛ ne anwo kpole, na ɔ...' [59.62s - 69.18s] (9.6s, 23 words) -> segment_000232.wav
# Saved segment 9: 'Kakula raalɛ ne hɔbizale ɔ nli Hɛlɔdease adwenle l...' [69.98s - 76.48s] (6.5s, 18 words) -> segment_000233.wav
# Saved segment 10: 'Na kakula ne hɔhanle hilele Hɛlɔdo kɛ, Medie Dwɔn ...' [77.22s - 84.06s] (6.8s, 17 words) -> segment_000234.wav
# Saved segment 11: 'Nyane hanle belemgbunli ne, noko kɛmɔ yeha ndane w...' [85.02s - 95.18s] (10.2s, 27 words) -> segment_000235.wav
# Saved segment 12: 'Yemɔti Hɛlɔdo manle bɛhɔpɛle Dwɔn ati wɔ efiade ne...' [95.80s - 100.04s] (4.2s, 9 words) -> segment_000236.wav
# Saved segment 13: 'Bɛvale tile ne bɛdole apawa nu bɛrɛlɛle kakula raa...' [100.78s - 107.38s] (6.6s, 17 words) -> segment_000237.wav
# Saved segment 14: 'Dwɔn ɛdoavolɛma ne raliele funli ne hɔziele ye, na...' [108.02s - 113.84s] (5.8s, 12 words) -> segment_000238.wav
# Saved segment 15: 'Gyisɛse maa menli apenle nnu aleɛ....' [113.88s - 114.68s] (0.8s, 6 words) -> segment_000239.wav
# Saved segment 16: 'Mɔɔ Gyisɛse dele Dwɔn Sɔnevolɛ ne ewule amaneɛ la,...' [114.72s - 124.80s] (10.1s, 26 words) -> segment_000240.wav
# Saved segment 17: 'Menli ne dele la, bɛvi bɛ azua ne mɔ azo bɛvale az...' [125.44s - 130.32s] (4.9s, 14 words) -> segment_000241.wav
# Saved segment 18: 'Gyisɛse tolole rale azule ne anloa na ɔnwunle menl...' [131.30s - 142.06s] (10.8s, 27 words) -> segment_000242.wav
# Saved segment 19: 'Ɔdwule nɔsolɛ nu la, ye ɛdoavolɛma ne rahanle hile...' [142.68s - 156.02s] (13.3s, 34 words) -> segment_000243.wav
# Saved segment 20: 'Gyisɛse zele bɛ kɛ, Ɔngyia kɛ bɛkɛhɔ; bɛdabɛ bɛmaa...' [156.92s - 161.46s] (4.5s, 12 words) -> segment_000244.wav
# Saved segment 21: 'Bɛbuale ye kɛ, Yɛnlɛ debie biala wɔ ɛke kɛ kpanwo ...' [162.36s - 168.70s] (6.3s, 16 words) -> segment_000245.wav
# Saved segment 22: 'Gyisɛse zele bɛ kɛ, Bɛva bɛrɛlɛ me....' [169.72s - 172.50s] (2.8s, 7 words) -> segment_000246.wav
# Saved segment 23: 'Akee ɔmanle menli ne mɔ dɛnlanle aze wɔ ndile ne a...' [173.50s - 183.92s] (10.4s, 26 words) -> segment_000247.wav
# Saved segment 24: 'Ɔbubule nuhua na ɔvale ɔmanle ye ɛdoavolɛma ne, na...' [184.66s - 190.04s] (5.4s, 15 words) -> segment_000248.wav
# Saved segment 25: 'Na bɛ muala bɛlile na bɛ ko yile....' [190.94s - 192.72s] (1.8s, 8 words) -> segment_000249.wav
# Saved segment 26: 'Nzinlii ɛdoavolɛma ne sesale ɔ bo zo ne ahɛndɛne b...' [193.32s - 197.28s] (4.0s, 12 words) -> segment_000250.wav
# Saved segment 27: 'Na bɛdabɛ mɔɔ bɛlile la, saa ɛye mraalɛ nee ngakul...' [197.92s - 204.78s] (6.9s, 19 words) -> segment_000251.wav
# Saved segment 28: 'Gyisɛse tia azule nye....' [204.92s - 206.44s] (1.5s, 4 words) -> segment_000252.wav
# Saved segment 29: 'Akee Gyisɛse manle ye ɛdoavolɛma ne vole ɛlɛne nu ...' [206.48s - 215.52s] (9.0s, 25 words) -> segment_000253.wav
# Saved segment 30: 'Mɔɔ menli ne hɔle la, ɔdaye ɔ ngome ɔhɔle boka ne ...' [216.52s - 221.32s] (4.8s, 14 words) -> segment_000254.wav
# Saved segment 31: 'Aleɛ muanle nwo la, ɛnee yeha ɔdaye ɔ ngome ala wɔ...' [221.94s - 235.12s] (13.2s, 35 words) -> segment_000255.wav
# Saved segment 32: 'Mɔɔ ɔdwule akɔlɛmɔleɛ la, Gyisɛse diale azule ne a...' [236.02s - 241.16s] (5.1s, 15 words) -> segment_000256.wav
# Saved segment 33: 'Mɔɔ ɛdoavolɛma ne nwunle ye kɛ ɔlɛtia azule ne any...' [241.84s - 251.40s] (9.6s, 24 words) -> segment_000257.wav
# Saved segment 34: 'Na ɛkɛ ne ala Gyisɛse zele bɛ kɛ, Bɛmmasulo, bɛha ...' [252.52s - 258.38s] (5.9s, 18 words) -> segment_000258.wav
# Saved segment 35: 'Pita hanle kɛ, Awulae, saa ɛdawɔ amgba a, ɛnee maa...' [259.28s - 266.52s] (7.2s, 21 words) -> segment_000259.wav
# Saved segment 36: 'Gyisɛse zele ye kɛ, Bɛla!...' [267.50s - 269.62s] (2.1s, 5 words) -> segment_000260.wav
# Saved segment 37: 'Yemɔti Pita vi ɛlɛne ne anu dwule na ɔbɔle ɔ bo kɛ...' [270.60s - 276.26s] (5.7s, 20 words) -> segment_000261.wav
# Saved segment 38: 'Na mɔɔ ɔnwunle kɛ anwoma ne anloa yɛ se la, ye aho...' [276.80s - 282.74s] (5.9s, 19 words) -> segment_000262.wav
# Saved segment 39: 'Na ɔdeanle nu kɛ, Awulae, die me....' [283.42s - 286.76s] (3.3s, 7 words) -> segment_000263.wav
# Saved segment 40: 'Ɛkɛ ne ala Gyisɛse denrɛle ɔ sa zɔle ye na ɔzele y...' [287.68s - 293.64s] (6.0s, 19 words) -> segment_000264.wav
# Saved segment 41: 'Duzu ati a ɛ ti anu yɛle wɔ kesee ɛ....' [294.30s - 296.00s] (1.7s, 10 words) -> segment_000265.wav
# Saved segment 42: 'Bɛ mu nwiɔ bɛvole ɛlɛne ne anu, na anwoma ne gyinl...' [296.98s - 299.72s] (2.7s, 11 words) -> segment_000266.wav
# Saved segment 43: 'Na ɛdoavolɛma ne mɔɔ wɔ ɛlɛne ne anu la rayeyɛle G...' [300.32s - 308.52s] (8.2s, 20 words) -> segment_000267.wav
# Saved segment 44: 'Gyisɛse yɛ wuleravolɛma ayile wɔ Gɛnɛzalɛte....' [308.56s - 309.54s] (1.0s, 6 words) -> segment_000268.wav
# Saved segment 45: 'Gyisɛse nee ye ɛdoavolɛma ne pɛle tandane ne hɔle ...' [309.58s - 316.26s] (6.7s, 19 words) -> segment_000269.wav
# Saved segment 46: 'Yemɔti bɛmanle bɛhɔvale wuleravolɛma mɔɔ wɔ namuna...' [316.98s - 333.42s] (16.4s, 36 words) -> segment_000270.wav
# Saved segment 47: 'Na bɛdabɛ mɔɔ bɛvale bɛ sa bɛhanle ye tɛladeɛ ne l...' [334.14s - 341.22s] (7.1s, 14 words) -> segment_000271.wav
# ✓ Completed MAT.14: Created 47 segments (skipped 0 segments > 2min)
# --------------------------------------------------
# Processing pair: MAT.15.wav + MAT.15.txt
# Original text: MAT 15. Mɔmoane amra ngilehilelɛ ne. Falasiima bie nee mɛla kilehilevolɛma mɔɔ vi Gyɛlusalɛm la rayi...
# Found 869 words
# Text segments (sentences): 59
# Grouped into 59 sentence segments
# Saved segment 1: 'MAT 15....' [0.68s - 0.98s] (0.3s, 2 words) -> segment_000272.wav
# Saved segment 2: 'Mɔmoane amra ngilehilelɛ ne....' [1.04s - 2.66s] (1.6s, 4 words) -> segment_000273.wav
# Saved segment 3: 'Falasiima bie nee mɛla kilehilevolɛma mɔɔ vi Gyɛlu...' [4.30s - 15.40s] (11.1s, 34 words) -> segment_000274.wav
# Saved segment 4: 'Bɛnnrinzi bɛ sa anwo wɔ adenle kpalɛ zo na bɛali d...' [16.10s - 18.92s] (2.8s, 11 words) -> segment_000275.wav
# Saved segment 5: 'Gyisɛse buale bɛ kɛ, Na bɛdabɛ noko kɛmɔti a bɛnli...' [19.80s - 26.74s] (6.9s, 22 words) -> segment_000276.wav
# Saved segment 6: 'Ɔluakɛ Nyamenle se, Di ɛ ze nee ɛ nli eni, na awie...' [27.66s - 35.18s] (7.5s, 28 words) -> segment_000277.wav
# Saved segment 7: 'Noko bɛmɛ bɛse, Saa awie lɛ debie mɔɔ ɔkola ɔfa ɔb...' [36.08s - 49.42s] (13.3s, 43 words) -> segment_000278.wav
# Saved segment 8: 'Zɔhane ati bɛva bɛ amaamuo zɛhae bɛdu Nyamenle Edw...' [50.00s - 54.14s] (4.1s, 11 words) -> segment_000279.wav
# Saved segment 9: 'Bɛmɛ nabalabama!...' [54.98s - 56.28s] (1.3s, 2 words) -> segment_000280.wav
# Saved segment 10: 'Ayezaya nwunle ye bɔkɔɔ yɛɛ ɔhanle ye wɔ bɛ nwo a....' [56.92s - 59.10s] (2.2s, 11 words) -> segment_000281.wav
# Saved segment 11: 'Ɔse....' [59.54s - 59.74s] (0.2s, 1 words) -> segment_000282.wav
# Saved segment 12: 'Nyamenle se: Menli ɛhye mɔ fa bɛ nloa babonle mgba...' [60.08s - 62.88s] (2.8s, 11 words) -> segment_000283.wav
# Saved segment 13: 'me, na bɛ ahonle ɛdeɛ, ɔmbikye me....' [62.96s - 65.58s] (2.6s, 7 words) -> segment_000284.wav
# Saved segment 14: 'Bɛ ɛzonlenlɛ ne le mgbane....' [66.50s - 68.14s] (1.6s, 5 words) -> segment_000285.wav
# Saved segment 15: 'ɔluakɛ bɛkilehile mɔɔ menli ɛhyehyɛ la kɛ asɛɛ me ...' [68.84s - 72.32s] (3.5s, 11 words) -> segment_000286.wav
# Saved segment 16: '....' [72.34s - 72.36s] (0.0s, 1 words) -> segment_000287.wav
# Saved segment 17: 'Ninyɛne mɔɔ gua sonla nwo evinli la....' [72.40s - 73.76s] (1.4s, 7 words) -> segment_000288.wav
# Saved segment 18: 'Akee Gyisɛse vɛlɛle menli dɔɔnwo ne wɔ ɔ nwo ɛkɛ n...' [73.88s - 79.30s] (5.4s, 17 words) -> segment_000289.wav
# Saved segment 19: 'Tɛ mɔɔ kɔ sonla nloa nu la a gua ɔ nwo evinli a, n...' [79.82s - 84.74s] (4.9s, 27 words) -> segment_000290.wav
# Saved segment 20: 'Nzinlii, ɛdoavolɛma ne rale Gyisɛse anwo ɛkɛ rahan...' [85.68s - 93.70s] (8.0s, 23 words) -> segment_000291.wav
# Saved segment 21: 'Gyisɛse buale kɛ, Baka biala mɔɔ tɛ Egya mɔɔ wɔ an...' [94.60s - 100.44s] (5.8s, 19 words) -> segment_000292.wav
# Saved segment 22: 'Bɛgyakyi bɛ!...' [101.14s - 101.64s] (0.5s, 2 words) -> segment_000293.wav
# Saved segment 23: 'Bɛle mgbanyinli anyenzinliravolɛma mɔɔ kile anyenz...' [102.36s - 110.68s] (8.3s, 19 words) -> segment_000294.wav
# Saved segment 24: 'Na Pita hanle kɛ, Kile yɛ ɛrɛlɛ ne abo....' [111.66s - 114.82s] (3.2s, 9 words) -> segment_000295.wav
# Saved segment 25: 'Gyisɛse zele bɛ kɛ, Na ɛnɛ nee ɛnɛ bɛdabɛ noko bɛn...' [115.78s - 122.20s] (6.4s, 19 words) -> segment_000296.wav
# Saved segment 26: 'Bɛnwu ye kɛ debie biala mɔɔ sonla kɛva kɛwula ɔ nl...' [122.92s - 129.16s] (6.2s, 21 words) -> segment_000297.wav
# Saved segment 27: 'Na mɔɔ vi bɛ nloa nu finde la vi ahonle nu, na bɛm...' [130.08s - 134.60s] (4.5s, 19 words) -> segment_000298.wav
# Saved segment 28: 'Ɔluakɛ ahonle nu yɛɛ adwenle ɛtane mɔɔ le kɛ sonla...' [135.38s - 146.46s] (11.1s, 24 words) -> segment_000299.wav
# Saved segment 29: 'Ninyɛne ɛhye mɔ a gua sonla nwo evinli a, na bɛ sa...' [147.34s - 152.48s] (5.1s, 23 words) -> segment_000300.wav
# Saved segment 30: 'Raalɛ bie diedi....' [152.52s - 154.58s] (2.1s, 3 words) -> segment_000301.wav
# Saved segment 31: 'Gyisɛse vile ɛkɛ ne na ɔhɔle azuamgbole Taya nee S...' [154.66s - 160.52s] (5.9s, 13 words) -> segment_000302.wav
# Saved segment 32: 'Raalɛ bie mɔɔ boka maanyɛlɛ fane ne mɔɔ bɛfɛlɛ ye ...' [161.20s - 173.58s] (12.4s, 30 words) -> segment_000303.wav
# Saved segment 33: 'Nwu me anwunvɔne!...' [174.40s - 175.48s] (1.1s, 3 words) -> segment_000304.wav
# Saved segment 34: 'Sunsum ɛtane bie ɛlɛgyegye me ra raalɛ, na kɛkala ...' [176.28s - 181.00s] (4.7s, 13 words) -> segment_000305.wav
# Saved segment 35: 'Na Gyisɛse andɛne ye zo....' [181.98s - 183.38s] (1.4s, 5 words) -> segment_000306.wav
# Saved segment 36: 'Na ye ɛdoavolɛma ne rale rabodole ye kɛ, Nea raalɛ...' [183.90s - 190.56s] (6.7s, 18 words) -> segment_000307.wav
# Saved segment 37: 'Gyisɛse buale kɛ, Bɛzoanle me wɔ mboane ne mɔɔ wɔ ...' [191.50s - 197.86s] (6.4s, 16 words) -> segment_000308.wav
# Saved segment 38: 'Raalɛ ne radule dɔle Gyisɛse agyakɛ anu bodole ye ...' [198.84s - 205.38s] (6.5s, 15 words) -> segment_000309.wav
# Saved segment 39: 'Gyisɛse buale ye kɛ, Ɔnle kpalɛ kɛ bɛkɛva aleɛ mɔɔ...' [206.54s - 212.80s] (6.3s, 18 words) -> segment_000310.wav
# Saved segment 40: 'Raalɛ ne zele ye kɛ, Yɛmenle, ɔle zɔhane, noko ake...' [213.78s - 224.52s] (10.7s, 27 words) -> segment_000311.wav
# Saved segment 41: 'Gyisɛse buale ye kɛ, Ɛle raalɛ mɔɔ wɔ diedi le kpo...' [225.64s - 229.32s] (3.7s, 13 words) -> segment_000312.wav
# Saved segment 42: 'Mɔɔ ɛkpondɛ la ɛyɛ ɛkɛ ɛmaa wɔ....' [230.00s - 232.10s] (2.1s, 7 words) -> segment_000313.wav
# Saved segment 43: 'Na raalɛ ne ara raalɛ ne dele kpɔkɛ ɛkɛ ne ala....' [233.06s - 235.60s] (2.5s, 11 words) -> segment_000314.wav
# Saved segment 44: 'Gyisɛse yɛ menli dɔɔnwo ayile....' [235.72s - 237.72s] (2.0s, 5 words) -> segment_000315.wav
# Saved segment 45: 'Gyisɛse vile ɛkɛ, ɔsianenle Galeli Tandane ne, ɔhɔ...' [237.76s - 243.38s] (5.6s, 13 words) -> segment_000316.wav
# Saved segment 46: 'Menli dɔɔnwo kpalɛ vale abuburama, anyenzinliravol...' [244.20s - 256.26s] (12.1s, 25 words) -> segment_000317.wav
# Saved segment 47: 'Mɔɔ menli ne nwunle kɛ mumule ɛlɛtendɛ, abubura ɛl...' [257.22s - 270.52s] (13.3s, 28 words) -> segment_000318.wav
# Saved segment 48: 'Gyisɛse maa menli apenle nna aleɛ....' [270.56s - 272.28s] (1.7s, 6 words) -> segment_000319.wav
# Saved segment 49: 'Gyisɛse vɛlɛle ye ɛdoavolɛma ne na ɔzele bɛ kɛ, Me...' [272.32s - 282.20s] (9.9s, 26 words) -> segment_000320.wav
# Saved segment 50: 'Mengulo kɛ bɛfa bɛ ko mgbane bɛsia bɛkɔ, anrɛɛ bɛ ...' [282.84s - 287.54s] (4.7s, 17 words) -> segment_000321.wav
# Saved segment 51: 'Ye ɛdoavolɛma ne bizale ye kɛ, Ɛnee nienwu a yɛkɛn...' [288.44s - 297.32s] (8.9s, 24 words) -> segment_000322.wav
# Saved segment 52: 'Gyisɛse bizale bɛ kɛ, Kpanwo nyɛ a bɛlɛ a....' [298.40s - 301.22s] (2.8s, 9 words) -> segment_000323.wav
# Saved segment 53: 'Bɛbuale kɛ, Kpanwo mumua nsuu yɛɛ fɛlɛ ekyi....' [302.16s - 306.54s] (4.4s, 8 words) -> segment_000324.wav
# Saved segment 54: 'Gyisɛse manle menli ne dɛnlanle aze....' [306.58s - 309.38s] (2.8s, 6 words) -> segment_000325.wav
# Saved segment 55: 'Akee ɔvale kpanwo mumua nsuu ne nee fɛlɛ ne, ɔyɛle...' [310.02s - 321.86s] (11.8s, 27 words) -> segment_000326.wav
# Saved segment 56: 'Bɛ muala bɛlile bɛ ko yile....' [322.78s - 324.12s] (1.3s, 6 words) -> segment_000327.wav
# Saved segment 57: 'Na ɛdoavolɛma ne sesale ɔ bo zo mgbokpoloka ne ahɛ...' [324.66s - 329.26s] (4.6s, 12 words) -> segment_000328.wav
# Saved segment 58: 'Menli mɔɔ lile la, saa ɛye mraalɛ nee ngakula mɔɔ ...' [329.86s - 336.54s] (6.7s, 19 words) -> segment_000329.wav
# Saved segment 59: 'Akee Gyisɛse gyakyile bɛ adenle na ɔvole ɛlɛne nu ...' [337.56s - 345.40s] (7.8s, 13 words) -> segment_000330.wav
# ✓ Completed MAT.15: Created 59 segments (skipped 0 segments > 2min)
# --------------------------------------------------
# Processing pair: MAT.12.wav + MAT.12.txt
# Original text: MAT 12. Ɛnwomenlelielɛ Kenle ne anwo kpuyia. Mekɛ ekyi guale nu la, ɛnee Gyisɛse lua abɛlɛ ɛya bie a...
# Found 1230 words
# Text segments (sentences): 79
# Grouped into 79 sentence segments
# Saved segment 1: 'MAT 12....' [0.68s - 0.96s] (0.3s, 2 words) -> segment_000331.wav
# Saved segment 2: 'Ɛnwomenlelielɛ Kenle ne anwo kpuyia....' [1.00s - 2.64s] (1.6s, 5 words) -> segment_000332.wav
# Saved segment 3: 'Mekɛ ekyi guale nu la, ɛnee Gyisɛse lua abɛlɛ ɛya ...' [4.10s - 9.90s] (5.8s, 16 words) -> segment_000333.wav
# Saved segment 4: 'Ɛhɔne hunle ye ɛdoavolɛma ne, yemɔti bɛbubule bie ...' [10.50s - 14.72s] (4.2s, 9 words) -> segment_000334.wav
# Saved segment 5: 'Falasiima bie mɔ nwunle ɛhye la bɛzele Gyisɛse kɛ,...' [15.44s - 26.12s] (10.7s, 26 words) -> segment_000335.wav
# Saved segment 6: 'Gyisɛse buale bɛ kɛ, Asoo bɛtɛkengale mɔɔ Devidi y...' [27.06s - 36.90s] (9.8s, 25 words) -> segment_000336.wav
# Saved segment 7: 'Se Devidi hɔle Nyamenle Sua ne anu na ɔhɔvale azu ...' [37.96s - 49.18s] (11.2s, 28 words) -> segment_000337.wav
# Saved segment 8: 'Anzɛɛ bɛtɛkengale ye wɔ Mosisi mɛla ne anu kɛ sɛlɛ...' [50.10s - 61.10s] (11.0s, 29 words) -> segment_000338.wav
# Saved segment 9: 'Meka meahile bɛ, awie mɔɔ le kpole tɛla Ɛzonlenlɛ ...' [62.00s - 65.88s] (3.9s, 14 words) -> segment_000339.wav
# Saved segment 10: 'Nyamenle Edwɛkɛ ne se, Mekpondɛ anwunvɔnezelɛ na t...' [66.48s - 71.26s] (4.8s, 11 words) -> segment_000340.wav
# Saved segment 11: 'Saa bɛte ɛhye abo kpalɛ a, anrɛɛ bɛmbu bɛdabɛ mɔɔ ...' [71.84s - 76.04s] (4.2s, 15 words) -> segment_000341.wav
# Saved segment 12: 'Ɔluakɛ medame, Sonla Ra, melɛ tumi wɔ Ɛnwomenlelie...' [76.88s - 82.08s] (5.2s, 12 words) -> segment_000342.wav
# Saved segment 13: 'Nrenya ne mɔɔ asa ko ɛdwe la....' [82.12s - 83.02s] (0.9s, 7 words) -> segment_000343.wav
# ...
# Saved segment 31: 'Na ɛnelɛ bie vi anwuma zele kɛ, Ɛhye a le me Ra mɔ...' [168.50s - 173.42s] (4.9s, 16 words) -> segment_001508.wav
# Saved segment 32: 'Me nye die ɔ nwo kpole....' [174.08s - 177.34s] (3.3s, 6 words) -> segment_001509.wav
# ✓ Completed MAT.3: Created 32 segments (skipped 0 segments > 2min)
# --------------------------------------------------
# Processing pair: MAT.18.wav + MAT.18.txt
# Original text: MAT 18. Nwane a le kpole kpalɛ a? Mekɛ ne anu ɛdoavolɛma ne rale Gyisɛse ɛkɛ rabizale ye kɛ, Nwane a...
# Found 961 words
# Text segments (sentences): 53
# Grouped into 53 sentence segments
# Saved segment 1: 'MAT 18....' [0.70s - 1.40s] (0.7s, 2 words) -> segment_001510.wav
# Saved segment 2: 'Nwane a le kpole kpalɛ a?...' [1.56s - 2.86s] (1.3s, 6 words) -> segment_001511.wav
# Saved segment 3: 'Mekɛ ne anu ɛdoavolɛma ne rale Gyisɛse ɛkɛ rabizal...' [4.44s - 12.50s] (8.1s, 21 words) -> segment_001512.wav
# Saved segment 4: 'Gyisɛse vɛlɛle kakula ko na ɔmanle ɔragyinlanle bɛ...' [13.70s - 21.12s] (7.4s, 17 words) -> segment_001513.wav
# Saved segment 5: 'Kyesɛ bɛkakyi bɛ nyɛleɛ na bɛyɛ kɛ ngakula la, anr...' [21.92s - 27.78s] (5.9s, 15 words) -> segment_001514.wav
# Saved segment 6: 'Mɔɔ le kpole kpalɛ wɔ Anwuma Belemgbunlililɛ nu la...' [28.68s - 34.52s] (5.8s, 24 words) -> segment_001515.wav
# Saved segment 7: 'Awie biala mɔɔ kɛlie kakula zɛhae ko wɔ me duma nu...' [35.38s - 39.36s] (4.0s, 15 words) -> segment_001516.wav
# Saved segment 8: 'Sɔnea mɔɔ twe sonla kɔ ɛtane nu la....' [39.40s - 40.30s] (0.9s, 8 words) -> segment_001517.wav
# Saved segment 9: 'Awie ko biala mɔɔ kɛmaa ngakula ɛhye mɔ anu ko kɛg...' [40.36s - 56.30s] (15.9s, 45 words) -> segment_001518.wav
# Saved segment 10: 'Munzule ɛha aleɛabo amra kɛ ninyɛne mɔɔ maa sonla ...' [57.20s - 62.82s] (5.6s, 18 words) -> segment_001519.wav
# Saved segment 11: 'Kɛ ɔkɛyɛ biala la, zɛhae ngyegyelɛ ne mɔ bara, nok...' [63.48s - 69.42s] (5.9s, 21 words) -> segment_001520.wav
# Saved segment 12: 'Saa ɛ sa anzɛɛ ɛ gyakɛ gyegye wɔ yeamaa wɔaminli w...' [70.32s - 74.92s] (4.6s, 16 words) -> segment_001521.wav
# Saved segment 13: 'Ɔle kpalɛ kɛ ɛ sa anzɛɛ ɛ gyakɛ kɛyɛ sinli na ɛkɛn...' [75.60s - 86.20s] (10.6s, 36 words) -> segment_001522.wav
# Saved segment 14: 'Saa ɛ nye ko a gyegye wɔ yeamaa wɔaminli wɔ diedi ...' [87.16s - 90.76s] (3.6s, 15 words) -> segment_001523.wav
# Saved segment 15: 'Ɔle kpalɛ kɛ ɛ nye ko na ɛkɛnyia ngoane mɔɔ ɛnlɛ a...' [91.46s - 99.04s] (7.6s, 28 words) -> segment_001524.wav
# Saved segment 16: 'Boane ne mɔɔ minlinle la....' [99.08s - 100.26s] (1.2s, 5 words) -> segment_001525.wav
# Saved segment 17: 'Bɛnlea na bɛambu ngakula ɛhye mɔ anu biala, kɛ ɔle...' [100.30s - 108.44s] (8.1s, 24 words) -> segment_001526.wav
# Saved segment 18: 'Ɔluakɛ medame Sonla Ra, membale kɛ mebalie bɛdabɛ ...' [109.08s - 112.74s] (3.7s, 12 words) -> segment_001527.wav
# Saved segment 19: 'Na duzu a bɛdwenle kɛ awie mɔɔ lɛ mboane ɛya ko na...' [113.66s - 117.98s] (4.3s, 18 words) -> segment_001528.wav
# Saved segment 20: 'Ɔgyakyi abulahɔnla nee ngɔnla ne wɔ bɛ adidileka n...' [118.82s - 124.10s] (5.3s, 16 words) -> segment_001529.wav
# Saved segment 21: 'Mese, saa ɔnwu ye a, ɔdi fɛlɛko kpole wɔ nwo ɔtɛla...' [125.04s - 132.00s] (7.0s, 18 words) -> segment_001530.wav
# Saved segment 22: 'Zɔhane ala noko yɛɛ bɛ Ze mɔɔ wɔ anwuma la ɛmkpond...' [133.06s - 138.58s] (5.5s, 19 words) -> segment_001531.wav
# Saved segment 23: 'Adiema mɔɔ kɛyɛ ɛtane la....' [138.62s - 139.70s] (1.1s, 5 words) -> segment_001532.wav
# Saved segment 24: 'Saa ɛ diema bie fo wɔ a, kɔ na ɛ nee ye bɛ mu nwiɔ...' [139.74s - 146.12s] (6.4s, 24 words) -> segment_001533.wav
# Saved segment 25: 'Saa ɔtie wɔ edwɛkɛ a ɛnee ɛ sa ɛha ɛ diema ne....' [146.74s - 150.38s] (3.6s, 12 words) -> segment_001534.wav
# Saved segment 26: 'Saa yeamkponle a, fa sonla ko anzɛɛ menli nwiɔ bok...' [151.24s - 160.88s] (9.6s, 32 words) -> segment_001535.wav
# Saved segment 27: 'Saa yeandie bɛ edwɛkɛ a, ka kile asɔnema amuala....' [161.78s - 164.46s] (2.7s, 9 words) -> segment_001536.wav
# Saved segment 28: 'Eza saa ɔnrɛdie asɔnema amuala noko edwɛkɛ a, ɛnee...' [165.38s - 171.46s] (6.1s, 19 words) -> segment_001537.wav
# Saved segment 29: 'Edwɛkɛ bo ɛhyelɛ nee ye ɛtululɛ....' [171.52s - 172.38s] (0.9s, 6 words) -> segment_001538.wav
# Saved segment 30: 'Nɔhalɛ, meka meahile bɛ: Debie biala mɔɔ bɛkɛkyeky...' [172.42s - 182.36s] (9.9s, 35 words) -> segment_001539.wav
# Saved segment 31: 'Eza meka meahile bɛ: Saa bɛ nuhua nwiɔ yɛ ko wɔ az...' [183.24s - 192.32s] (9.1s, 30 words) -> segment_001540.wav
# Saved segment 32: 'Ɔluakɛ ɛleka biala mɔɔ menli nwiɔ anzɛɛ nsa kɛyia ...' [192.96s - 199.72s] (6.8s, 22 words) -> segment_001541.wav
# Saved segment 33: 'Sonvolɛ ne mɔɔ anva angyɛ la anwo ɛrɛlɛ....' [199.92s - 202.16s] (2.2s, 8 words) -> segment_001542.wav
# Saved segment 34: 'Akee Pita hɔle Gyisɛse anwo ɛkɛ hɔbizale ye kɛ, Aw...' [202.20s - 209.34s] (7.1s, 22 words) -> segment_001543.wav
# Saved segment 35: 'Fane nsuu, anzɛɛ....' [209.98s - 211.42s] (1.4s, 3 words) -> segment_001544.wav
# Saved segment 36: '....' [216.98s - 217.22s] (0.2s, 1 words) -> segment_001545.wav
# Saved segment 37: 'Gyisɛse buale ye kɛ, Kyɛkyɛ, tɛ fane nsuu, na abul...' [212.34s - 216.92s] (4.6s, 11 words) -> segment_001546.wav
# Saved segment 38: 'Zɔhane ati bɛbava Anwuma Belemgbunlililɛ ne bɛado ...' [218.12s - 225.92s] (7.8s, 20 words) -> segment_001547.wav
# Saved segment 39: 'Mekɛ mɔɔ bɛhɔle mgbondabulɛ ne azo la, bɛvale ko m...' [226.58s - 232.44s] (5.9s, 18 words) -> segment_001548.wav
# Saved segment 40: 'Sonvolɛ ɛhye ɛnlɛ bie, yemɔti yeannyia bie yeandua...' [233.30s - 236.98s] (3.7s, 11 words) -> segment_001549.wav
# Saved segment 41: 'Na ɔ menle ne zele kɛ bɛhɔdɔne ɔdaye sonvolɛ mumua...' [237.68s - 247.68s] (10.0s, 31 words) -> segment_001550.wav
# Saved segment 42: 'Sonvolɛ ne dule dɔle ɔ menle ne agyakɛ anu na ɔzɛl...' [248.54s - 256.64s] (8.1s, 24 words) -> segment_001551.wav
# Saved segment 43: 'Alɔbɔlɛ hanle belemgbunli ne na ɔgyakyile ye ɔmanl...' [257.30s - 262.46s] (5.2s, 16 words) -> segment_001552.wav
# Saved segment 44: 'Sonvolɛ ne vindele la, ɔnwunle ɔ gɔnwo sonvolɛ ko ...' [263.36s - 269.32s] (6.0s, 20 words) -> segment_001553.wav
# Saved segment 45: 'Ɔhɔzɔle ɔ kɔmenzia na ɔzele ye kɛ, Tua me ezukoa n...' [269.90s - 273.18s] (3.3s, 13 words) -> segment_001554.wav
# Saved segment 46: 'Ɔ gɔnwo sonvolɛ ne ɔdaye ɔdule ɔdɔle ɔ gyakɛ anu ɛ...' [274.14s - 281.84s] (7.7s, 27 words) -> segment_001555.wav
# Saved segment 47: 'Noko yeamkponle; ɔhyele ye ɔhɔdole efiade kɔkpula ...' [282.52s - 287.26s] (4.7s, 13 words) -> segment_001556.wav
# Saved segment 48: 'Mɔɔ ɔ gɔnwo sonvolɛma ne mɔ nwunle mɔɔ yeyɛ la nya...' [288.18s - 296.04s] (7.9s, 23 words) -> segment_001557.wav
# Saved segment 49: 'Belemgbunli ne vɛlɛle ye na ɔzele ye kɛ, Ɛdawɔ akɛ...' [296.94s - 302.36s] (5.4s, 20 words) -> segment_001558.wav
# Saved segment 50: 'Ɛbodole me la, mame menvale wɔ kakɛ ne amuala meng...' [302.88s - 306.26s] (3.4s, 11 words) -> segment_001559.wav
# Saved segment 51: 'Anrɛɛ ɛnee ɔwɔ kɛ ɛdawɔ noko ɛnwu ɛ gɔnwo sonvolɛ ...' [306.82s - 311.50s] (4.7s, 17 words) -> segment_001560.wav
# Saved segment 52: 'Belemgbunli ne vale ɛya kpole na ɔmanle bɛhɔdole y...' [312.38s - 319.04s] (6.7s, 22 words) -> segment_001561.wav
# Saved segment 53: 'Na Gyisɛse dwulale ye edwɛkɛ ne kɛ, Zɔhane ala yɛɛ...' [319.98s - 334.34s] (14.4s, 37 words) -> segment_001562.wav
# ✓ Completed MAT.18: Created 53 segments (skipped 0 segments > 2min)
# --------------------------------------------------
# Processing pair: MAT.1.wav + MAT.1.txt
# Original text: MAT 1. Gyisɛse Kelaese abusua ɛlɔnwɔne ne. Gyisɛse Kelaese abusua ɛlɔnwɔne ne ɛne. Gyisɛse le Devidi...
# Found 445 words
# Text segments (sentences): 20
# Grouped into 20 sentence segments
# Saved segment 1: 'MAT 1....' [0.54s - 0.64s] (0.1s, 2 words) -> segment_001563.wav
# Saved segment 2: 'Gyisɛse Kelaese abusua ɛlɔnwɔne ne....' [0.70s - 4.84s] (4.1s, 5 words) -> segment_001564.wav
# Saved segment 3: 'Gyisɛse Kelaese abusua ɛlɔnwɔne ne ɛne....' [6.50s - 8.44s] (1.9s, 6 words) -> segment_001565.wav
# Saved segment 4: 'Gyisɛse le Devidi angabɛnzo yɛɛ Devidi le Ebileham...' [9.10s - 13.70s] (4.6s, 9 words) -> segment_001566.wav
# Saved segment 5: 'Ebileham wole Ayezeke, Ayezeke wole Gyekɔbo, Gyekɔ...' [14.54s - 20.52s] (6.0s, 14 words) -> segment_001567.wav
# Saved segment 6: 'Dwuda wole Pɛlɛze nee Zila , Pɛlɛze wole Hɛzelɔn, ...' [21.46s - 49.14s] (27.7s, 37 words) -> segment_001568.wav
# Saved segment 7: 'Devidi wole Sɔlɔmɔn , Sɔlɔmɔn wole Rilihɔbowam; Ri...' [49.94s - 90.62s] (40.7s, 48 words) -> segment_001569.wav
# Saved segment 8: 'Mekɛ ɛhye anu yɛɛ Babelɔnoma hyele Dwuda maanlema ...' [91.30s - 97.32s] (6.0s, 12 words) -> segment_001570.wav
# Saved segment 9: 'Bɛvale bɛ bɛhɔle Babelɔn la nzinlii Gyɛhɔyakɛn wol...' [98.26s - 133.90s] (35.6s, 56 words) -> segment_001571.wav
# Saved segment 10: 'Zɔhane ati, ɔvi Ebileham anwo zo toonwo mɔɔ badwu ...' [134.80s - 158.52s] (23.7s, 55 words) -> segment_001572.wav
# Saved segment 11: 'Gyisɛse Kelaese awolɛ ne....' [158.60s - 160.82s] (2.2s, 4 words) -> segment_001573.wav
# Saved segment 12: 'Kɛ Gyisɛse Kelaese awolɛ ne yɛle la ɛne....' [160.90s - 162.84s] (1.9s, 8 words) -> segment_001574.wav
# Saved segment 13: 'Mekɛ mɔɔ Dwosefi yiale Mɛle, mɔɔ le Gyisɛse ɔ nli ...' [163.68s - 175.88s] (12.2s, 29 words) -> segment_001575.wav
# Saved segment 14: 'Kɛmɔ ɛnee Dwosefi le sonla mɔɔ di pɛlepɛle na yean...' [176.68s - 186.50s] (9.8s, 26 words) -> segment_001576.wav
# Saved segment 15: 'Na mekɛ mɔɔ ɛnee Dwosefi ɛlɛdwenledwenle ɛhye anwo...' [187.38s - 205.02s] (17.6s, 43 words) -> segment_001577.wav
# Saved segment 16: 'Ɔbawo ralɛ nrenya na wɔado ye duma Gyisɛse, ɔboale...' [205.92s - 212.54s] (6.6s, 17 words) -> segment_001578.wav
# Saved segment 17: 'Ɛhye mɔ amuala zile amaa mɔɔ Awulae luale ye kpɔma...' [213.36s - 225.78s] (12.4s, 31 words) -> segment_001579.wav
# Saved segment 18: 'Ɛhye ati mɔɔ Dwosefi vi nla nu dwazole la, ɔyɛle y...' [228.00s - 234.92s] (6.9s, 21 words) -> segment_001580.wav
# Saved segment 19: 'Noko yeanva ɔ nwo yeanga Mɛle toonwo ɔhɔkpulale me...' [235.68s - 243.06s] (7.4s, 17 words) -> segment_001581.wav
# Saved segment 20: 'Na Dwosefi donle ye Gyisɛse....' [243.86s - 248.12s] (4.3s, 5 words) -> segment_001582.wav
# ✓ Completed MAT.1: Created 20 segments (skipped 0 segments > 2min)
# --------------------------------------------------
# Processing pair: MAT.7.wav + MAT.7.txt
# Original text: MAT 7. Awie mɔ ndɛne ɛbualɛ. Bɛmmabua awie mɔ ndɛne na Nyamenle ambua bɛ ndɛne, ɔboalekɛ ndɛne mɔɔ b...
# Found 653 words
# Text segments (sentences): 42
# Grouped into 42 sentence segments
# Saved segment 1: 'MAT 7....' [0.66s - 0.96s] (0.3s, 2 words) -> segment_001583.wav
# Saved segment 2: 'Awie mɔ ndɛne ɛbualɛ....' [1.00s - 4.22s] (3.2s, 4 words) -> segment_001584.wav
# Saved segment 3: 'Bɛmmabua awie mɔ ndɛne na Nyamenle ambua bɛ ndɛne,...' [4.26s - 16.98s] (12.7s, 34 words) -> segment_001585.wav
# Saved segment 4: 'Duzu ati a ɛnwu mumunli mɔɔ la ɛ diema anye zo, na...' [17.92s - 24.14s] (6.2s, 23 words) -> segment_001586.wav
# Saved segment 5: 'Anzɛɛ duzu ati yɛɛ ɛse ɛ diema kɛ, Mebodo wɔ, maa ...' [24.92s - 34.02s] (9.1s, 30 words) -> segment_001587.wav
# Saved segment 6: 'Wɔmɔ nabalabanli!...' [34.96s - 36.14s] (1.2s, 2 words) -> segment_001588.wav
# Saved segment 7: 'Dumua ye dubinli ne mɔɔ la ɛ nye zo la na wɔanwu d...' [36.76s - 44.46s] (7.7s, 27 words) -> segment_001589.wav
# Saved segment 8: 'Bɛmmafa debie mɔɔ anwo te la bɛmaa ahwea, na bɛkɛp...' [45.36s - 56.46s] (11.1s, 26 words) -> segment_001590.wav
# Saved segment 9: 'Biza, kpondɛ, bɔ nu....' [56.62s - 57.30s] (0.7s, 4 words) -> segment_001591.wav
# Saved segment 10: 'Bɛbiza na bɛ sa kɛha ye; bɛkpondɛ na bɛkɛnwu ye; b...' [57.34s - 62.34s] (5.0s, 15 words) -> segment_001592.wav
# Saved segment 11: 'Ɔluakɛ awie biala mɔɔ biza la asa ka ye; mɔɔ kpond...' [62.90s - 69.24s] (6.3s, 21 words) -> segment_001593.wav
# Saved segment 12: 'Bɛ nuhua boni yɛɛ saa ɔ ra biza ye kpanwo a ɔkɛva ...' [70.14s - 74.48s] (4.3s, 16 words) -> segment_001594.wav
# Saved segment 13: 'Anzɛɛ saa ɔbiza ye fɛlɛ a ɔkɛmaa ye ɛwɔlɛ a?...' [75.02s - 77.88s] (2.9s, 10 words) -> segment_001595.wav
# Saved segment 14: 'Na saa bɛmɛ mɔɔ bɛle ɛtanevolɛma la bɛze kɛ ɔwɔ kɛ...' [78.26s - 89.76s] (11.5s, 38 words) -> segment_001596.wav
# Saved segment 15: 'Zɔhane ati mɔɔ bɛkpondɛ kɛ menli yɛ maa bɛ la, bɛd...' [90.74s - 95.42s] (4.7s, 17 words) -> segment_001597.wav
# Saved segment 16: 'Mosisi mɛla ne nee Nyamenle kpɔmanvolɛma ngilehile...' [95.94s - 99.64s] (3.7s, 13 words) -> segment_001598.wav
# Saved segment 17: 'Anuhɔlɛ ɛdenraa ne....' [99.74s - 100.68s] (0.9s, 3 words) -> segment_001599.wav
# Saved segment 18: 'Bɛva anuhɔlɛ ɛdenraa ne anu bɛwolo, ɔluakɛ anuhɔlɛ...' [100.72s - 112.42s] (11.7s, 33 words) -> segment_001600.wav
# Saved segment 19: 'Na anuhɔlɛ ne mɔɔ kɔ ngoane mɔɔ ɛnlɛ awieleɛ la an...' [113.44s - 122.94s] (9.5s, 29 words) -> segment_001601.wav
# Saved segment 20: 'Baka nee ye ma....' [122.98s - 123.66s] (0.7s, 4 words) -> segment_001602.wav
# Saved segment 21: 'Bɛnlea bɛ nwo boɛ wɔ Nyamenle kpɔmanvolɛma alanema...' [123.70s - 132.90s] (9.2s, 26 words) -> segment_001603.wav
# Saved segment 22: 'Menli zɔhane mɔ nyɛleɛ yɛɛ bɛbava bɛanwu bɛ a....' [133.72s - 136.14s] (2.4s, 9 words) -> segment_001604.wav
# Saved segment 23: 'Kolokolonyɛma ɛnzo vanye ma, yɛɛ evileni ɛnzo feeg...' [136.80s - 140.22s] (3.4s, 9 words) -> segment_001605.wav
# Saved segment 24: 'Baka kpalɛ biala so ma kpalɛ, yɛɛ baka ɛtane so ma...' [140.54s - 144.36s] (3.8s, 12 words) -> segment_001606.wav
# Saved segment 25: 'Baka kpalɛ ɛnzo ma ɛtane, yɛɛ baka ɛtane ɛnzo ma k...' [144.84s - 148.40s] (3.6s, 11 words) -> segment_001607.wav
# Saved segment 26: 'Baka biala mɔɔ ɛnzo ma kpalɛ la bɛpɛ ye bɛto na bɛ...' [149.18s - 153.62s] (4.4s, 14 words) -> segment_001608.wav
# Saved segment 27: 'Zɔhane ala yɛɛ bɛbalua Nyamenle kpɔmanvolɛma alane...' [154.06s - 159.52s] (5.5s, 12 words) -> segment_001609.wav
# Saved segment 28: 'Menze bɛ....' [159.72s - 160.36s] (0.6s, 2 words) -> segment_001610.wav
# Saved segment 29: 'Tɛ awie biala mɔɔ kɛvɛlɛ me kɛ, Awulae, Awulae la ...' [160.40s - 170.74s] (10.3s, 34 words) -> segment_001611.wav
# Saved segment 30: 'Saa Ndɛnebualɛ Kenle ne dwu a, dɔɔnwo ne ala baha ...' [171.76s - 176.08s] (4.3s, 15 words) -> segment_001612.wav
# Saved segment 31: 'Yɛluale wɔ duma nu yɛbɔle Edwɛkpa ne nolo, yɛluale...' [176.48s - 183.82s] (7.3s, 19 words) -> segment_001613.wav
# Saved segment 32: 'Na mebaze bɛ kɛ, Menze bɛ....' [184.82s - 186.72s] (1.9s, 6 words) -> segment_001614.wav
# Saved segment 33: 'Bɛvi ɛkɛ ne bɛhɔ....' [187.18s - 188.10s] (0.9s, 4 words) -> segment_001615.wav
# Saved segment 34: 'Nindavoma....' [188.58s - 188.74s] (0.2s, 1 words) -> segment_001616.wav
# Saved segment 35: 'Suazilɛma nwiɔ ne....' [188.78s - 189.34s] (0.6s, 3 words) -> segment_001617.wav
# Saved segment 36: 'Zɔhane ati awie biala mɔɔ tie me edwɛkɛ ne na ɔdi ...' [189.98s - 197.64s] (7.7s, 25 words) -> segment_001618.wav
# Saved segment 37: 'Ezule kpole dɔle na azule yile bule aze, na ahumu ...' [198.68s - 206.36s] (7.7s, 21 words) -> segment_001619.wav
# Saved segment 38: 'Awie noko mɔɔ tie me edwɛkɛ ne na ɔnli zolɛ la le ...' [206.74s - 212.04s] (5.3s, 23 words) -> segment_001620.wav
# Saved segment 39: 'Ezule dɔle, azule yile bule aze, ahumu dule kpole ...' [212.94s - 219.06s] (6.1s, 16 words) -> segment_001621.wav
# Saved segment 40: 'Na ye azedɔlɛ ne yɛle ɛzulolɛ....' [219.50s - 221.44s] (1.9s, 6 words) -> segment_001622.wav
# Saved segment 41: 'Gyisɛse tumi ne....' [221.48s - 222.48s] (1.0s, 3 words) -> segment_001623.wav
# Saved segment 42: 'Mɔɔ Gyisɛse wiele ɛhye mɔ ka la, ye ngilehilelɛ ne...' [222.56s - 238.02s] (15.5s, 31 words) -> segment_001624.wav
# ✓ Completed MAT.7: Created 42 segments (skipped 0 segments > 2min)
# --------------------------------------------------
# Writing metadata to /content/splits/metadata.csv...
# All done! Created 1624 audio segments in /content/splits/wav
# Metadata saved to /content/splits/metadata.csv with 1624 entries

# %% [markdown]
# WORD-LEVEL ALLIGN

# %%
import torch
from ctc_forced_aligner import (
    load_audio,
    load_alignment_model,
    generate_emissions,
    preprocess_text,
    get_alignments,
    get_spans,
    postprocess_results,
)
from pydub import AudioSegment
import os

# Input folders
audio_folder = "/content/wav"
text_folder = "/content/txt"
output_root = "/content/splits/"

language = "twi"  # ISO-639-3 Language code
device = "cuda" if torch.cuda.is_available() else "cpu"
batch_size = 16

os.makedirs(output_root, exist_ok=True)

# Load alignment model and tokenizer once
alignment_model, alignment_tokenizer = load_alignment_model(
    device,
    dtype=torch.float16 if device == "cuda" else torch.float32,
)

# Iterate over all wav files
for audio_filename in os.listdir(audio_folder):
    if not audio_filename.lower().endswith(".wav"):
        continue

    base_name = os.path.splitext(audio_filename)[0]
    output_folder = os.path.join(output_root, base_name)

    # Skip processing if output folder already exists
    if os.path.exists(output_folder):
        print(f"Output folder for '{base_name}' already exists, skipping...")
        continue

    audio_path = os.path.join(audio_folder, audio_filename)
    text_path = os.path.join(text_folder, base_name + ".txt")

    if not os.path.isfile(text_path):
        print(f"Warning: Text file not found for {audio_filename}, skipping...")
        continue

    print(f"Processing pair: {audio_filename} + {base_name}.txt")

    # Load audio waveform
    audio_waveform = load_audio(audio_path, alignment_model.dtype, alignment_model.device)

    # Read and preprocess text
    with open(text_path, "r") as f:
        lines = f.readlines()
    text = "".join(line for line in lines).replace("\n", " ").strip()

    # Generate emissions (model output probabilities)
    emissions, stride = generate_emissions(
        alignment_model, audio_waveform, batch_size=batch_size
    )

    # Preprocess text
    tokens_starred, text_starred = preprocess_text(
        text,
        romanize=True,
        language=language,
    )

    # Get alignments between audio and text tokens
    segments, scores, blank_token = get_alignments(
        emissions,
        tokens_starred,
        alignment_tokenizer,
    )

    # Get spans (start/end indices) for each token
    spans = get_spans(tokens_starred, segments, blank_token)

    # Postprocess to get word-level timestamps
    word_timestamps = postprocess_results(text_starred, spans, stride, scores)

    # Load original audio for splitting
    audio = AudioSegment.from_wav(audio_path)

    # Create output folder per file
    os.makedirs(output_folder, exist_ok=True)

    # Save each word segment as separate audio file
    for i, word_info in enumerate(word_timestamps):
        start_ms = int(word_info['start'] * 1000)
        end_ms = int(word_info['end'] * 1000)

        segment_audio = audio[start_ms:end_ms]

        word = word_info['text'].replace(" ", "_").replace("/", "_")

        out_file = os.path.join(output_folder, f"{i:03d}_{word}.wav")

        segment_audio.export(out_file, format="wav")
        print(f"Saved segment {i}: '{word}' [{word_info['start']:.2f}s - {word_info['end']:.2f}s] -> {out_file}")

print("All done!")
# Out:
# Processing pair: KMK6wnOP-Tmp069-OY8Qws.wav + KMK6wnOP-Tmp069-OY8Qws.txt
# Saved segment 0: 'Transcription:' [0.86s - 1.20s] -> /content/splits/KMK6wnOP-Tmp069-OY8Qws/000_Transcription:.wav
# Saved segment 1: 'Saa' [1.30s - 1.39s] -> /content/splits/KMK6wnOP-Tmp069-OY8Qws/001_Saa.wav
# Saved segment 2: 'ɔkɔdeɛ' [1.68s - 1.89s] -> /content/splits/KMK6wnOP-Tmp069-OY8Qws/002_ɔkɔdeɛ.wav
# Saved segment 3: 'no' [1.93s - 1.95s] -> /content/splits/KMK6wnOP-Tmp069-OY8Qws/003_no.wav
# Saved segment 4: 'Translation:' [2.00s - 2.35s] -> /content/splits/KMK6wnOP-Tmp069-OY8Qws/004_Translation:.wav
# Saved segment 5: 'That' [2.39s - 2.46s] -> /content/splits/KMK6wnOP-Tmp069-OY8Qws/005_That.wav
# Saved segment 6: 'eagle' [2.50s - 3.09s] -> /content/splits/KMK6wnOP-Tmp069-OY8Qws/006_eagle.wav
# Processing pair: JSVVb30H-Tmp027-6pPivl.wav + JSVVb30H-Tmp027-6pPivl.txt
# Saved segment 0: 'Transcription:' [0.48s - 0.78s] -> /content/splits/JSVVb30H-Tmp027-6pPivl/000_Transcription:.wav
# Saved segment 1: 'Na' [0.82s - 0.84s] -> /content/splits/JSVVb30H-Tmp027-6pPivl/001_Na.wav
# Saved segment 2: 'biribiara' [0.99s - 1.34s] -> /content/splits/JSVVb30H-Tmp027-6pPivl/002_biribiara.wav
# Saved segment 3: 'dwoi' [1.39s - 1.47s] -> /content/splits/JSVVb30H-Tmp027-6pPivl/003_dwoi.wav
# Saved segment 4: 'Translation:' [1.51s - 1.81s] -> /content/splits/JSVVb30H-Tmp027-6pPivl/004_Translation:.wav
# Saved segment 5: 'For' [1.85s - 1.89s] -> /content/splits/JSVVb30H-Tmp027-6pPivl/005_For.wav
# Saved segment 6: 'everything' [1.93s - 2.12s] -> /content/splits/JSVVb30H-Tmp027-6pPivl/006_everything.wav
# Saved segment 7: 'to' [2.16s - 2.18s] -> /content/splits/JSVVb30H-Tmp027-6pPivl/007_to.wav
# Saved segment 8: 'cool' [2.23s - 2.31s] -> /content/splits/JSVVb30H-Tmp027-6pPivl/008_cool.wav
# Saved segment 9: 'down' [2.35s - 2.58s] -> /content/splits/JSVVb30H-Tmp027-6pPivl/009_down.wav
# Processing pair: SSeKyJuQ-Tmp045-MMpXYd.wav + SSeKyJuQ-Tmp045-MMpXYd.txt
# Saved segment 0: 'Transcription:' [1.66s - 1.97s] -> /content/splits/SSeKyJuQ-Tmp045-MMpXYd/000_Transcription:.wav
# Saved segment 1: 'Woo' [2.02s - 2.12s] -> /content/splits/SSeKyJuQ-Tmp045-MMpXYd/001_Woo.wav
# Saved segment 2: 'tɔ' [2.25s - 2.39s] -> /content/splits/SSeKyJuQ-Tmp045-MMpXYd/002_tɔ.wav
# Saved segment 3: 'akɔ' [2.46s - 2.50s] -> /content/splits/SSeKyJuQ-Tmp045-MMpXYd/003_akɔ.wav
# Saved segment 4: 'number' [2.54s - 2.71s] -> /content/splits/SSeKyJuQ-Tmp045-MMpXYd/004_number.wav
# Saved segment 5: 'bɛn' [2.75s - 2.79s] -> /content/splits/SSeKyJuQ-Tmp045-MMpXYd/005_bɛn.wav
# Saved segment 6: 'so' [2.83s - 2.92s] -> /content/splits/SSeKyJuQ-Tmp045-MMpXYd/006_so.wav
# Saved segment 7: 'Translation:' [2.96s - 3.25s] -> /content/splits/SSeKyJuQ-Tmp045-MMpXYd/007_Translation:.wav
# Saved segment 8: 'Which' [3.34s - 3.42s] -> /content/splits/SSeKyJuQ-Tmp045-MMpXYd/008_Which.wav
# Saved segment 9: 'number' [3.46s - 3.59s] -> /content/splits/SSeKyJuQ-Tmp045-MMpXYd/009_number.wav
# Saved segment 10: 'are' [3.63s - 3.70s] -> /content/splits/SSeKyJuQ-Tmp045-MMpXYd/010_are.wav
# Saved segment 11: 'you' [3.74s - 3.78s] -> /content/splits/SSeKyJuQ-Tmp045-MMpXYd/011_you.wav
# Saved segment 12: 'buying' [4.03s - 4.22s] -> /content/splits/SSeKyJuQ-Tmp045-MMpXYd/012_buying.wav
# Saved segment 13: 'to' [4.26s - 4.70s] -> /content/splits/SSeKyJuQ-Tmp045-MMpXYd/013_to.wav
# Processing pair: KOQdPViN-Tmp026-DGtok3.wav + KOQdPViN-Tmp026-DGtok3.txt
# Saved segment 0: 'Transcription:' [0.36s - 2.75s] -> /content/splits/KOQdPViN-Tmp026-DGtok3/000_Transcription:.wav
# Saved segment 1: 'Na' [2.79s - 2.86s] -> /content/splits/KOQdPViN-Tmp026-DGtok3/001_Na.wav
# Saved segment 2: 'ɔkɔe' [3.04s - 3.15s] -> /content/splits/KOQdPViN-Tmp026-DGtok3/002_ɔkɔe.wav
# Saved segment 3: 'kowui' [3.19s - 3.49s] -> /content/splits/KOQdPViN-Tmp026-DGtok3/003_kowui.wav
# Saved segment 4: 'Translation:' [3.53s - 3.95s] -> /content/splits/KOQdPViN-Tmp026-DGtok3/004_Translation:.wav
# Saved segment 5: 'He' [4.09s - 4.18s] -> /content/splits/KOQdPViN-Tmp026-DGtok3/005_He.wav
# Saved segment 6: 'went' [4.33s - 4.45s] -> /content/splits/KOQdPViN-Tmp026-DGtok3/006_went.wav
# Saved segment 7: 'to' [4.49s - 4.51s] -> /content/splits/KOQdPViN-Tmp026-DGtok3/007_to.wav
# Saved segment 8: 'die' [4.56s - 5.75s] -> /content/splits/KOQdPViN-Tmp026-DGtok3/008_die.wav
# Processing pair: JDerKnm8-Tmp071-QC2KB3.wav + JDerKnm8-Tmp071-QC2KB3.txt
# Saved segment 0: 'Transcription:' [0.38s - 0.73s] -> /content/splits/JDerKnm8-Tmp071-QC2KB3/000_Transcription:.wav
# Saved segment 1: 'Akwadaa' [0.82s - 1.01s] -> /content/splits/JDerKnm8-Tmp071-QC2KB3/001_Akwadaa.wav
# Saved segment 2: 'wei' [1.05s - 1.09s] -> /content/splits/JDerKnm8-Tmp071-QC2KB3/002_wei.wav
# Saved segment 3: 'Translation:' [1.13s - 1.34s] -> /content/splits/JDerKnm8-Tmp071-QC2KB3/003_Translation:.wav
# Saved segment 4: 'This' [1.39s - 1.45s] -> /content/splits/JDerKnm8-Tmp071-QC2KB3/004_This.wav
# Saved segment 5: 'child' [1.49s - 2.18s] -> /content/splits/JDerKnm8-Tmp071-QC2KB3/005_child.wav
# Processing pair: DMlDyLuq-Tmp104-7Yx4IF.wav + DMlDyLuq-Tmp104-7Yx4IF.txt
# Saved segment 0: 'Transcription:' [0.02s - 0.36s] -> /content/splits/DMlDyLuq-Tmp104-7Yx4IF/000_Transcription:.wav
# Saved segment 1: 'Wote' [0.42s - 0.53s] -> /content/splits/DMlDyLuq-Tmp104-7Yx4IF/001_Wote.wav
# Saved segment 2: 'borɔfo' [0.57s - 0.67s] -> /content/splits/DMlDyLuq-Tmp104-7Yx4IF/002_borɔfo.wav
# Saved segment 3: 'Translation:' [0.71s - 1.01s] -> /content/splits/DMlDyLuq-Tmp104-7Yx4IF/003_Translation:.wav
# Saved segment 4: 'Do' [1.05s - 1.07s] -> /content/splits/DMlDyLuq-Tmp104-7Yx4IF/004_Do.wav
# Saved segment 5: 'you' [1.11s - 1.16s] -> /content/splits/DMlDyLuq-Tmp104-7Yx4IF/005_you.wav
# Saved segment 6: 'understand' [1.20s - 1.43s] -> /content/splits/DMlDyLuq-Tmp104-7Yx4IF/006_understand.wav
# Saved segment 7: 'english' [1.47s - 2.08s] -> /content/splits/DMlDyLuq-Tmp104-7Yx4IF/007_english.wav
# Processing pair: ITzf6beh-Tmp091-XNowRj.wav + ITzf6beh-Tmp091-XNowRj.txt
# Saved segment 0: 'Transcription:' [0.08s - 0.40s] -> /content/splits/ITzf6beh-Tmp091-XNowRj/000_Transcription:.wav
# Saved segment 1: 'Efiri' [0.67s - 0.76s] -> /content/splits/ITzf6beh-Tmp091-XNowRj/001_Efiri.wav
# Saved segment 2: 'sɛ' [0.80s - 0.82s] -> /content/splits/ITzf6beh-Tmp091-XNowRj/002_sɛ.wav
# Saved segment 3: 'Translation:' [0.86s - 1.13s] -> /content/splits/ITzf6beh-Tmp091-XNowRj/003_Translation:.wav
# Saved segment 4: 'Because' [1.18s - 1.85s] -> /content/splits/ITzf6beh-Tmp091-XNowRj/004_Because.wav
# Saved segment 5: 'of' [2.02s - 2.14s] -> /content/splits/ITzf6beh-Tmp091-XNowRj/005_of.wav
# Processing pair: SKUDJnDU-Tmp091-o1EX74.wav + SKUDJnDU-Tmp091-o1EX74.txt
# Saved segment 0: 'Transcription:' [0.06s - 1.11s] -> /content/splits/SKUDJnDU-Tmp091-o1EX74/000_Transcription:.wav
# Saved segment 1: 'Efiri' [1.16s - 1.24s] -> /content/splits/SKUDJnDU-Tmp091-o1EX74/001_Efiri.wav
# Saved segment 2: 'sɛ' [1.30s - 1.32s] -> /content/splits/SKUDJnDU-Tmp091-o1EX74/002_sɛ.wav
# Saved segment 3: 'Translation:' [1.36s - 1.57s] -> /content/splits/SKUDJnDU-Tmp091-o1EX74/003_Translation:.wav
# Saved segment 4: 'Because' [1.62s - 1.78s] -> /content/splits/SKUDJnDU-Tmp091-o1EX74/004_Because.wav
# Saved segment 5: 'of' [1.83s - 1.95s] -> /content/splits/SKUDJnDU-Tmp091-o1EX74/005_of.wav
# Processing pair: MHFMF5Wm-Tmp124-rDQZKA.wav + MHFMF5Wm-Tmp124-rDQZKA.txt
# Saved segment 0: 'Transcription:' [2.23s - 2.79s] -> /content/splits/MHFMF5Wm-Tmp124-rDQZKA/000_Transcription:.wav
# Saved segment 1: 'To' [2.83s - 2.86s] -> /content/splits/MHFMF5Wm-Tmp124-rDQZKA/001_To.wav
# Saved segment 2: 'so' [2.90s - 2.98s] -> /content/splits/MHFMF5Wm-Tmp124-rDQZKA/002_so.wav
# Saved segment 3: 'ma' [3.04s - 3.07s] -> /content/splits/MHFMF5Wm-Tmp124-rDQZKA/003_ma.wav
# Saved segment 4: 'me' [3.11s - 3.13s] -> /content/splits/MHFMF5Wm-Tmp124-rDQZKA/004_me.wav
# Saved segment 5: 'Translation:' [3.17s - 3.38s] -> /content/splits/MHFMF5Wm-Tmp124-rDQZKA/005_Translation:.wav
# Saved segment 6: 'Add' [3.42s - 3.49s] -> /content/splits/MHFMF5Wm-Tmp124-rDQZKA/006_Add.wav
# Saved segment 7: 'some' [3.53s - 3.59s] -> /content/splits/MHFMF5Wm-Tmp124-rDQZKA/007_some.wav
# Saved segment 8: 'more' [3.63s - 3.70s] -> /content/splits/MHFMF5Wm-Tmp124-rDQZKA/008_more.wav
# Processing pair: EDDji66v-Tmp081-xfoxq9.wav + EDDji66v-Tmp081-xfoxq9.txt
# Saved segment 0: 'Transcription:' [0.65s - 1.11s] -> /content/splits/EDDji66v-Tmp081-xfoxq9/000_Transcription:.wav
# Saved segment 1: 'Yaw' [1.18s - 1.22s] -> /content/splits/EDDji66v-Tmp081-xfoxq9/001_Yaw.wav
# Saved segment 2: 'ne' [1.26s - 1.30s] -> /content/splits/EDDji66v-Tmp081-xfoxq9/002_ne.wav
# Saved segment 3: 'Ama' [1.36s - 1.60s] -> /content/splits/EDDji66v-Tmp081-xfoxq9/003_Ama.wav
# Saved segment 4: 'Translation:' [1.64s - 1.89s] -> /content/splits/EDDji66v-Tmp081-xfoxq9/004_Translation:.wav
# Saved segment 5: 'Yaw' [1.95s - 2.04s] -> /content/splits/EDDji66v-Tmp081-xfoxq9/005_Yaw.wav
# Saved segment 6: 'and' [2.10s - 2.18s] -> /content/splits/EDDji66v-Tmp081-xfoxq9/006_and.wav
# Saved segment 7: 'Ama' [2.23s - 2.27s] -> /content/splits/EDDji66v-Tmp081-xfoxq9/007_Ama.wav
# Processing pair: AA59atVw-Tmp034-MN51js.wav + AA59atVw-Tmp034-MN51js.txt
# Saved segment 0: 'Transcription:' [0.44s - 0.97s] -> /content/splits/AA59atVw-Tmp034-MN51js/000_Transcription:.wav
# Saved segment 1: 'ɛte' [1.01s - 1.05s] -> /content/splits/AA59atVw-Tmp034-MN51js/001_ɛte.wav
# Saved segment 2: 'sɛn' [1.13s - 1.32s] -> /content/splits/AA59atVw-Tmp034-MN51js/002_sɛn.wav
# Saved segment 3: 'Translation:' [1.36s - 1.60s] -> /content/splits/AA59atVw-Tmp034-MN51js/003_Translation:.wav
# Saved segment 4: 'How' [1.64s - 1.68s] -> /content/splits/AA59atVw-Tmp034-MN51js/004_How.wav
# Saved segment 5: 'are' [1.72s - 1.78s] -> /content/splits/AA59atVw-Tmp034-MN51js/005_are.wav
# Saved segment 6: 'you' [1.83s - 1.89s] -> /content/splits/AA59atVw-Tmp034-MN51js/006_you.wav
# Processing pair: GAyYbBw7-Tmp089-UcAEzF.wav + GAyYbBw7-Tmp089-UcAEzF.txt
# Saved segment 0: 'Transcription:' [2.58s - 3.15s] -> /content/splits/GAyYbBw7-Tmp089-UcAEzF/000_Transcription:.wav
# Saved segment 1: 'Me' [3.19s - 3.21s] -> /content/splits/GAyYbBw7-Tmp089-UcAEzF/001_Me.wav
# Saved segment 2: 'ho' [3.28s - 3.32s] -> /content/splits/GAyYbBw7-Tmp089-UcAEzF/002_ho.wav
# Saved segment 3: 'yɛ' [3.36s - 3.38s] -> /content/splits/GAyYbBw7-Tmp089-UcAEzF/003_yɛ.wav
# Saved segment 4: 'pa' [3.49s - 3.51s] -> /content/splits/GAyYbBw7-Tmp089-UcAEzF/004_pa.wav
# Saved segment 5: 'ara' [3.61s - 3.72s] -> /content/splits/GAyYbBw7-Tmp089-UcAEzF/005_ara.wav
# Saved segment 6: 'Translation:' [3.76s - 3.97s] -> /content/splits/GAyYbBw7-Tmp089-UcAEzF/006_Translation:.wav
# Saved segment 7: 'I' [4.01s - 4.01s] -> /content/splits/GAyYbBw7-Tmp089-UcAEzF/007_I.wav
# Saved segment 8: 'am' [4.05s - 4.07s] -> /content/splits/GAyYbBw7-Tmp089-UcAEzF/008_am.wav
# Saved segment 9: 'very' [4.12s - 4.18s] -> /content/splits/GAyYbBw7-Tmp089-UcAEzF/009_very.wav
# Saved segment 10: 'well' [4.22s - 5.06s] -> /content/splits/GAyYbBw7-Tmp089-UcAEzF/010_well.wav
# Processing pair: SA1nhEic-Tmp048-0LJcBf.wav + SA1nhEic-Tmp048-0LJcBf.txt
# Saved segment 0: 'Transcription:' [0.02s - 0.29s] -> /content/splits/SA1nhEic-Tmp048-0LJcBf/000_Transcription:.wav
# Saved segment 1: 'Mepaa’kyɛw' [0.34s - 0.55s] -> /content/splits/SA1nhEic-Tmp048-0LJcBf/001_Mepaa’kyɛw.wav
# Saved segment 2: 'me' [0.61s - 0.65s] -> /content/splits/SA1nhEic-Tmp048-0LJcBf/002_me.wav
# Saved segment 3: 'pɛsɛ' [0.73s - 0.86s] -> /content/splits/SA1nhEic-Tmp048-0LJcBf/003_pɛsɛ.wav
# Saved segment 4: 'me' [0.92s - 0.94s] -> /content/splits/SA1nhEic-Tmp048-0LJcBf/004_me.wav
# Saved segment 5: 'tɔ' [0.99s - 1.01s] -> /content/splits/SA1nhEic-Tmp048-0LJcBf/005_tɔ.wav
# Saved segment 6: 'mtn' [1.05s - 1.09s] -> /content/splits/SA1nhEic-Tmp048-0LJcBf/006_mtn.wav
# Saved segment 7: 'credit' [1.13s - 1.24s] -> /content/splits/SA1nhEic-Tmp048-0LJcBf/007_credit.wav
# Saved segment 8: 'Translation:' [1.28s - 1.53s] -> /content/splits/SA1nhEic-Tmp048-0LJcBf/008_Translation:.wav
# Saved segment 9: 'Translation:' [1.66s - 1.95s] -> /content/splits/SA1nhEic-Tmp048-0LJcBf/009_Translation:.wav
# Saved segment 10: 'Please' [2.08s - 2.33s] -> /content/splits/SA1nhEic-Tmp048-0LJcBf/010_Please.wav
# Saved segment 11: 'I' [2.37s - 2.37s] -> /content/splits/SA1nhEic-Tmp048-0LJcBf/011_I.wav
# Saved segment 12: 'want' [2.42s - 2.48s] -> /content/splits/SA1nhEic-Tmp048-0LJcBf/012_want.wav
# Saved segment 13: 'to' [2.54s - 2.56s] -> /content/splits/SA1nhEic-Tmp048-0LJcBf/013_to.wav
# Saved segment 14: 'buy' [2.60s - 2.67s] -> /content/splits/SA1nhEic-Tmp048-0LJcBf/014_buy.wav
# Saved segment 15: 'mtn' [2.71s - 2.75s] -> /content/splits/SA1nhEic-Tmp048-0LJcBf/015_mtn.wav
# Saved segment 16: 'credit' [2.79s - 2.94s] -> /content/splits/SA1nhEic-Tmp048-0LJcBf/016_credit.wav
# Processing pair: oKqabEV0-Tmp065-5UaCfx.wav + oKqabEV0-Tmp065-5UaCfx.txt
# Saved segment 0: 'Transcription:' [2.67s - 2.92s] -> /content/splits/oKqabEV0-Tmp065-5UaCfx/000_Transcription:.wav
# Saved segment 1: 'Me' [2.96s - 2.98s] -> /content/splits/oKqabEV0-Tmp065-5UaCfx/001_Me.wav
# Saved segment 2: 'credit' [3.02s - 3.23s] -> /content/splits/oKqabEV0-Tmp065-5UaCfx/002_credit.wav
# Saved segment 3: 'aka' [3.55s - 3.70s] -> /content/splits/oKqabEV0-Tmp065-5UaCfx/003_aka.wav
# Saved segment 4: 'sɛn' [3.84s - 3.88s] -> /content/splits/oKqabEV0-Tmp065-5UaCfx/004_sɛn.wav
# Saved segment 5: 'Translation:' [3.93s - 4.14s] -> /content/splits/oKqabEV0-Tmp065-5UaCfx/005_Translation:.wav
# Saved segment 6: 'How' [4.18s - 4.22s] -> /content/splits/oKqabEV0-Tmp065-5UaCfx/006_How.wav
# Saved segment 7: 'much' [4.26s - 4.33s] -> /content/splits/oKqabEV0-Tmp065-5UaCfx/007_much.wav
# Saved segment 8: 'of' [4.37s - 4.41s] -> /content/splits/oKqabEV0-Tmp065-5UaCfx/008_of.wav
# Saved segment 9: 'my' [4.56s - 4.58s] -> /content/splits/oKqabEV0-Tmp065-5UaCfx/009_my.wav
# Saved segment 10: 'credit' [4.62s - 4.72s] -> /content/splits/oKqabEV0-Tmp065-5UaCfx/010_credit.wav
# Saved segment 11: 'is' [4.81s - 4.89s] -> /content/splits/oKqabEV0-Tmp065-5UaCfx/011_is.wav
# Saved segment 12: 'left' [4.93s - 6.34s] -> /content/splits/oKqabEV0-Tmp065-5UaCfx/012_left.wav
# Processing pair: MSJ1Bd5N-Tmp123-N4VRW8.wav + MSJ1Bd5N-Tmp123-N4VRW8.txt
# Saved segment 0: 'Transcription:' [0.23s - 2.10s] -> /content/splits/MSJ1Bd5N-Tmp123-N4VRW8/000_Transcription:.wav
# Saved segment 1: 'Te' [2.14s - 2.16s] -> /content/splits/MSJ1Bd5N-Tmp123-N4VRW8/001_Te.wav
# Saved segment 2: 'so' [2.21s - 2.23s] -> /content/splits/MSJ1Bd5N-Tmp123-N4VRW8/002_so.wav
# Saved segment 3: 'ma' [2.29s - 2.31s] -> /content/splits/MSJ1Bd5N-Tmp123-N4VRW8/003_ma.wav
# Saved segment 4: 'me' [2.35s - 2.37s] -> /content/splits/MSJ1Bd5N-Tmp123-N4VRW8/004_me.wav
# Saved segment 5: 'Translation:' [2.42s - 2.65s] -> /content/splits/MSJ1Bd5N-Tmp123-N4VRW8/005_Translation:.wav
# Saved segment 6: 'Reduce' [2.69s - 2.79s] -> /content/splits/MSJ1Bd5N-Tmp123-N4VRW8/006_Reduce.wav
# Saved segment 7: 'the' [2.83s - 2.88s] -> /content/splits/MSJ1Bd5N-Tmp123-N4VRW8/007_the.wav
# Saved segment 8: 'price' [2.92s - 3.07s] -> /content/splits/MSJ1Bd5N-Tmp123-N4VRW8/008_price.wav
# Saved segment 9: 'for' [3.15s - 3.23s] -> /content/splits/MSJ1Bd5N-Tmp123-N4VRW8/009_for.wav
# Saved segment 10: 'me' [3.28s - 3.30s] -> /content/splits/MSJ1Bd5N-Tmp123-N4VRW8/010_me.wav
# Processing pair: HAw1tWB0-Tmp070-83aogZ.wav + HAw1tWB0-Tmp070-83aogZ.txt
# Saved segment 0: 'Transcription:' [2.04s - 2.50s] -> /content/splits/HAw1tWB0-Tmp070-83aogZ/000_Transcription:.wav
# Saved segment 1: 'Mefri' [2.54s - 2.65s] -> /content/splits/HAw1tWB0-Tmp070-83aogZ/001_Mefri.wav
# Saved segment 2: 'Ghana' [2.77s - 2.90s] -> /content/splits/HAw1tWB0-Tmp070-83aogZ/002_Ghana.wav
# Saved segment 3: 'Translation:' [2.94s - 3.15s] -> /content/splits/HAw1tWB0-Tmp070-83aogZ/003_Translation:.wav
# Saved segment 4: 'I’m' [3.19s - 3.28s] -> /content/splits/HAw1tWB0-Tmp070-83aogZ/004_I’m.wav
# Saved segment 5: 'from' [3.32s - 3.38s] -> /content/splits/HAw1tWB0-Tmp070-83aogZ/005_from.wav
# Saved segment 6: 'Ghana' [3.42s - 3.88s] -> /content/splits/HAw1tWB0-Tmp070-83aogZ/006_Ghana.wav
# Processing pair: CCB9p7d5-Tmp078-doaZ2X.wav + CCB9p7d5-Tmp078-doaZ2X.txt
# Saved segment 0: 'Transcription:' [0.02s - 0.71s] -> /content/splits/CCB9p7d5-Tmp078-doaZ2X/000_Transcription:.wav
# Saved segment 1: 'Yɛ' [0.76s - 0.78s] -> /content/splits/CCB9p7d5-Tmp078-doaZ2X/001_Yɛ.wav
# Saved segment 2: 'wɔ' [0.88s - 0.94s] -> /content/splits/CCB9p7d5-Tmp078-doaZ2X/002_wɔ.wav
# Saved segment 3: 'Translation:' [0.99s - 1.28s] -> /content/splits/CCB9p7d5-Tmp078-doaZ2X/003_Translation:.wav
# Saved segment 4: 'We' [1.32s - 1.36s] -> /content/splits/CCB9p7d5-Tmp078-doaZ2X/004_We.wav
# Saved segment 5: 'have' [1.41s - 1.47s] -> /content/splits/CCB9p7d5-Tmp078-doaZ2X/005_have.wav
# Processing pair: FKfl5IQ1-Tmp103-6fyFok.wav + FKfl5IQ1-Tmp103-6fyFok.txt
# Saved segment 0: 'Transcription:' [0.08s - 1.03s] -> /content/splits/FKfl5IQ1-Tmp103-6fyFok/000_Transcription:.wav
# Saved segment 1: 'Wofiri' [1.07s - 1.26s] -> /content/splits/FKfl5IQ1-Tmp103-6fyFok/001_Wofiri.wav
# Saved segment 2: 'he' [1.30s - 1.32s] -> /content/splits/FKfl5IQ1-Tmp103-6fyFok/002_he.wav
# Saved segment 3: 'Translation:' [1.36s - 1.57s] -> /content/splits/FKfl5IQ1-Tmp103-6fyFok/003_Translation:.wav
# Saved segment 4: 'Where' [1.62s - 1.70s] -> /content/splits/FKfl5IQ1-Tmp103-6fyFok/004_Where.wav
# Saved segment 5: 'are' [1.78s - 1.83s] -> /content/splits/FKfl5IQ1-Tmp103-6fyFok/005_are.wav
# Saved segment 6: 'you' [1.87s - 1.91s] -> /content/splits/FKfl5IQ1-Tmp103-6fyFok/006_you.wav
# Saved segment 7: 'from' [1.97s - 2.08s] -> /content/splits/FKfl5IQ1-Tmp103-6fyFok/007_from.wav
# Processing pair: CAPRjwVE-Tmp015-A4KaY3.wav + CAPRjwVE-Tmp015-A4KaY3.txt
# Saved segment 0: 'Transcription:' [0.44s - 0.76s] -> /content/splits/CAPRjwVE-Tmp015-A4KaY3/000_Transcription:.wav
# Saved segment 1: 'Kɔɔ' [0.80s - 0.90s] -> /content/splits/CAPRjwVE-Tmp015-A4KaY3/001_Kɔɔ.wav
# Saved segment 2: 'dua' [0.94s - 0.99s] -> /content/splits/CAPRjwVE-Tmp015-A4KaY3/002_dua.wav
# Saved segment 3: 'bi' [1.03s - 1.05s] -> /content/splits/CAPRjwVE-Tmp015-A4KaY3/003_bi.wav
# Saved segment 4: 'akyi' [1.09s - 1.16s] -> /content/splits/CAPRjwVE-Tmp015-A4KaY3/004_akyi.wav
# Saved segment 5: 'Translation:' [1.20s - 1.49s] -> /content/splits/CAPRjwVE-Tmp015-A4KaY3/005_Translation:.wav
# Saved segment 6: 'Went' [1.53s - 1.72s] -> /content/splits/CAPRjwVE-Tmp015-A4KaY3/006_Went.wav
# Saved segment 7: 'behind' [1.76s - 1.95s] -> /content/splits/CAPRjwVE-Tmp015-A4KaY3/007_behind.wav
# Saved segment 8: 'a' [2.00s - 2.00s] -> /content/splits/CAPRjwVE-Tmp015-A4KaY3/008_a.wav
# Saved segment 9: 'certain' [2.04s - 2.16s] -> /content/splits/CAPRjwVE-Tmp015-A4KaY3/009_certain.wav
# Saved segment 10: 'a' [2.21s - 2.21s] -> /content/splits/CAPRjwVE-Tmp015-A4KaY3/010_a.wav
# Saved segment 11: 'tree' [2.25s - 2.75s] -> /content/splits/CAPRjwVE-Tmp015-A4KaY3/011_tree.wav
# Processing pair: HM7MwN94-Tmp035-sSKjps.wav + HM7MwN94-Tmp035-sSKjps.txt
# Saved segment 0: 'Transcription:' [0.02s - 0.97s] -> /content/splits/HM7MwN94-Tmp035-sSKjps/000_Transcription:.wav
# Saved segment 1: 'ɛyɛ' [1.01s - 1.05s] -> /content/splits/HM7MwN94-Tmp035-sSKjps/001_ɛyɛ.wav
# Saved segment 2: 'Translation:' [1.09s - 1.30s] -> /content/splits/HM7MwN94-Tmp035-sSKjps/002_Translation:.wav
# Saved segment 3: 'It’s' [1.34s - 1.49s] -> /content/splits/HM7MwN94-Tmp035-sSKjps/003_It’s.wav
# Saved segment 4: 'fine' [1.53s - 2.42s] -> /content/splits/HM7MwN94-Tmp035-sSKjps/004_fine.wav
# Processing pair: MAQYxgil-Tmp092-C7MU9Y.wav + MAQYxgil-Tmp092-C7MU9Y.txt
# Saved segment 0: 'Transcription:' [1.28s - 1.55s] -> /content/splits/MAQYxgil-Tmp092-C7MU9Y/000_Transcription:.wav
# Saved segment 1: 'Esian' [2.14s - 2.23s] -> /content/splits/MAQYxgil-Tmp092-C7MU9Y/001_Esian.wav
# Saved segment 2: 'sɛ' [2.50s - 2.52s] -> /content/splits/MAQYxgil-Tmp092-C7MU9Y/002_sɛ.wav
# Saved segment 3: 'Translation:' [2.67s - 2.88s] -> /content/splits/MAQYxgil-Tmp092-C7MU9Y/003_Translation:.wav
# Saved segment 4: 'Because' [3.02s - 3.78s] -> /content/splits/MAQYxgil-Tmp092-C7MU9Y/004_Because.wav
# Saved segment 5: 'of' [3.82s - 3.84s] -> /content/splits/MAQYxgil-Tmp092-C7MU9Y/005_of.wav
# Processing pair: ENzuHlXS-Tmp039-DyKfiS.wav + ENzuHlXS-Tmp039-DyKfiS.txt
# Saved segment 0: 'Transcription:' [2.77s - 3.04s] -> /content/splits/ENzuHlXS-Tmp039-DyKfiS/000_Transcription:.wav
# Saved segment 1: 'Network' [3.42s - 3.88s] -> /content/splits/ENzuHlXS-Tmp039-DyKfiS/001_Network.wav
# Saved segment 2: 'bɛn' [4.07s - 4.33s] -> /content/splits/ENzuHlXS-Tmp039-DyKfiS/002_bɛn.wav
# Saved segment 3: 'Translation:' [4.39s - 4.60s] -> /content/splits/ENzuHlXS-Tmp039-DyKfiS/003_Translation:.wav
# Saved segment 4: 'Which' [4.64s - 4.72s] -> /content/splits/ENzuHlXS-Tmp039-DyKfiS/004_Which.wav
# Saved segment 5: 'network' [4.77s - 4.91s] -> /content/splits/ENzuHlXS-Tmp039-DyKfiS/005_network.wav
# Processing pair: HAw1tWB0-Tmp122-hvCwFZ.wav + HAw1tWB0-Tmp122-hvCwFZ.txt
# Saved segment 0: 'Transcription:' [0.04s - 0.53s] -> /content/splits/HAw1tWB0-Tmp122-hvCwFZ/000_Transcription:.wav
# Saved segment 1: 'Yɛbehyia' [0.57s - 0.73s] -> /content/splits/HAw1tWB0-Tmp122-hvCwFZ/001_Yɛbehyia.wav
# Saved segment 2: 'biom' [0.78s - 0.86s] -> /content/splits/HAw1tWB0-Tmp122-hvCwFZ/002_biom.wav
# Saved segment 3: 'Translation:' [0.90s - 1.72s] -> /content/splits/HAw1tWB0-Tmp122-hvCwFZ/003_Translation:.wav
# Saved segment 4: 'We' [1.85s - 1.87s] -> /content/splits/HAw1tWB0-Tmp122-hvCwFZ/004_We.wav
# Saved segment 5: 'will' [2.12s - 2.31s] -> /content/splits/HAw1tWB0-Tmp122-hvCwFZ/005_will.wav
# Saved segment 6: 'meet' [2.35s - 2.44s] -> /content/splits/HAw1tWB0-Tmp122-hvCwFZ/006_meet.wav
# Saved segment 7: 'again' [2.54s - 2.96s] -> /content/splits/HAw1tWB0-Tmp122-hvCwFZ/007_again.wav
# Processing pair: YLPN6Hr0-Tmp067-mvmtdq.wav + YLPN6Hr0-Tmp067-mvmtdq.txt
# Saved segment 0: 'Transcription:' [2.31s - 2.62s] -> /content/splits/YLPN6Hr0-Tmp067-mvmtdq/000_Transcription:.wav
# Saved segment 1: 'Fa' [2.67s - 2.69s] -> /content/splits/YLPN6Hr0-Tmp067-mvmtdq/001_Fa.wav
# Saved segment 2: 'to' [2.73s - 2.75s] -> /content/splits/YLPN6Hr0-Tmp067-mvmtdq/002_to.wav
# Saved segment 3: 'hɔ' [2.79s - 2.81s] -> /content/splits/YLPN6Hr0-Tmp067-mvmtdq/003_hɔ.wav
# Saved segment 4: 'Translation:' [2.86s - 3.21s] -> /content/splits/YLPN6Hr0-Tmp067-mvmtdq/004_Translation:.wav
# Saved segment 5: 'Put' [3.28s - 3.36s] -> /content/splits/YLPN6Hr0-Tmp067-mvmtdq/005_Put.wav
# Saved segment 6: 'it' [3.40s - 3.42s] -> /content/splits/YLPN6Hr0-Tmp067-mvmtdq/006_it.wav
# Saved segment 7: 'there' [3.46s - 3.55s] -> /content/splits/YLPN6Hr0-Tmp067-mvmtdq/007_there.wav
# Processing pair: JMOC1VFS-Tmp012-RXLtt5.wav + JMOC1VFS-Tmp012-RXLtt5.txt
# Saved segment 0: 'Transcription:' [2.18s - 2.50s] -> /content/splits/JMOC1VFS-Tmp012-RXLtt5/000_Transcription:.wav
# Saved segment 1: 'Ne' [2.54s - 2.60s] -> /content/splits/JMOC1VFS-Tmp012-RXLtt5/001_Ne.wav
# Saved segment 2: 'nea' [2.65s - 2.71s] -> /content/splits/JMOC1VFS-Tmp012-RXLtt5/002_nea.wav
# Saved segment 3: 'Ɔsɛe' [2.94s - 3.34s] -> /content/splits/JMOC1VFS-Tmp012-RXLtt5/003_Ɔsɛe.wav
# Saved segment 4: 'de' [3.49s - 3.57s] -> /content/splits/JMOC1VFS-Tmp012-RXLtt5/004_de.wav
# Saved segment 5: 'yɛɛ' [3.70s - 3.84s] -> /content/splits/JMOC1VFS-Tmp012-RXLtt5/005_yɛɛ.wav
# Saved segment 6: 'buburoo' [3.91s - 4.18s] -> /content/splits/JMOC1VFS-Tmp012-RXLtt5/006_buburoo.wav
# Saved segment 7: 'wei' [4.22s - 4.28s] -> /content/splits/JMOC1VFS-Tmp012-RXLtt5/007_wei.wav
# Saved segment 8: 'Translation:' [4.33s - 4.56s] -> /content/splits/JMOC1VFS-Tmp012-RXLtt5/008_Translation:.wav
# Saved segment 9: 'Is' [4.60s - 4.62s] -> /content/splits/JMOC1VFS-Tmp012-RXLtt5/009_Is.wav
# Saved segment 10: 'what' [4.66s - 4.72s] -> /content/splits/JMOC1VFS-Tmp012-RXLtt5/010_what.wav
# Saved segment 11: 'Osei' [4.79s - 4.85s] -> /content/splits/JMOC1VFS-Tmp012-RXLtt5/011_Osei.wav
# Saved segment 12: 'did' [4.89s - 4.93s] -> /content/splits/JMOC1VFS-Tmp012-RXLtt5/012_did.wav
# Saved segment 13: 'to' [4.98s - 5.00s] -> /content/splits/JMOC1VFS-Tmp012-RXLtt5/013_to.wav
# Saved segment 14: 'this' [5.06s - 5.17s] -> /content/splits/JMOC1VFS-Tmp012-RXLtt5/014_this.wav
# Saved segment 15: 'buburoo' [5.21s - 5.36s] -> /content/splits/JMOC1VFS-Tmp012-RXLtt5/015_buburoo.wav
# Processing pair: SSeKyJuQ-Tmp014-HmbHEV.wav + SSeKyJuQ-Tmp014-HmbHEV.txt
# Saved segment 0: 'Transcription:' [0.50s - 1.57s] -> /content/splits/SSeKyJuQ-Tmp014-HmbHEV/000_Transcription:.wav
# Saved segment 1: 'Tuu' [1.66s - 2.02s] -> /content/splits/SSeKyJuQ-Tmp014-HmbHEV/001_Tuu.wav
# Saved segment 2: 'no' [2.21s - 2.31s] -> /content/splits/SSeKyJuQ-Tmp014-HmbHEV/002_no.wav
# Saved segment 3: 'Translation:' [2.60s - 2.86s] -> /content/splits/SSeKyJuQ-Tmp014-HmbHEV/003_Translation:.wav
# Saved segment 4: 'Evicted' [2.90s - 3.04s] -> /content/splits/SSeKyJuQ-Tmp014-HmbHEV/004_Evicted.wav
# Saved segment 5: 'him_her' [3.09s - 3.40s] -> /content/splits/SSeKyJuQ-Tmp014-HmbHEV/005_him_her.wav
# Processing pair: MG86GRGn-Tmp040-7fc839.wav + MG86GRGn-Tmp040-7fc839.txt
# Saved segment 0: 'Transcription:' [0.34s - 3.25s] -> /content/splits/MG86GRGn-Tmp040-7fc839/000_Transcription:.wav
# Saved segment 1: 'Mtn' [3.32s - 3.42s] -> /content/splits/MG86GRGn-Tmp040-7fc839/001_Mtn.wav
# Saved segment 2: 'Translation:' [3.46s - 4.01s] -> /content/splits/MG86GRGn-Tmp040-7fc839/002_Translation:.wav
# Saved segment 3: 'Mtn' [4.07s - 4.12s] -> /content/splits/MG86GRGn-Tmp040-7fc839/003_Mtn.wav
# Processing pair: PKxokOLV-Tmp117-mitn4L.wav + PKxokOLV-Tmp117-mitn4L.txt
# Saved segment 0: 'Transcription:' [0.02s - 1.81s] -> /content/splits/PKxokOLV-Tmp117-mitn4L/000_Transcription:.wav
# Saved segment 1: 'Nokware' [1.85s - 2.10s] -> /content/splits/PKxokOLV-Tmp117-mitn4L/001_Nokware.wav
# Saved segment 2: 'di' [2.21s - 2.29s] -> /content/splits/PKxokOLV-Tmp117-mitn4L/002_di.wav
# Saved segment 3: 'etuo' [2.39s - 2.52s] -> /content/splits/PKxokOLV-Tmp117-mitn4L/003_etuo.wav
# Saved segment 4: 'Translation:' [2.56s - 2.88s] -> /content/splits/PKxokOLV-Tmp117-mitn4L/004_Translation:.wav
# Saved segment 5: 'Truthfulness' [2.92s - 3.19s] -> /content/splits/PKxokOLV-Tmp117-mitn4L/005_Truthfulness.wav
# Saved segment 6: 'draws' [3.23s - 3.36s] -> /content/splits/PKxokOLV-Tmp117-mitn4L/006_draws.wav
# Saved segment 7: 'one' [3.40s - 3.44s] -> /content/splits/PKxokOLV-Tmp117-mitn4L/007_one.wav
# Saved segment 8: 'closer' [3.49s - 3.95s] -> /content/splits/PKxokOLV-Tmp117-mitn4L/008_closer.wav
# Saved segment 9: 'to' [4.07s - 4.12s] -> /content/splits/PKxokOLV-Tmp117-mitn4L/009_to.wav
# Saved segment 10: 'death' [4.16s - 4.24s] -> /content/splits/PKxokOLV-Tmp117-mitn4L/010_death.wav
# Processing pair: DMeKRfHu-Tmp077-8fguID.wav + DMeKRfHu-Tmp077-8fguID.txt
# Saved segment 0: 'Transcription:' [0.02s - 1.05s] -> /content/splits/DMeKRfHu-Tmp077-8fguID/000_Transcription:.wav
# Saved segment 1: 'Mame' [1.11s - 1.49s] -> /content/splits/DMeKRfHu-Tmp077-8fguID/001_Mame.wav
# Saved segment 2: 'bebree' [1.66s - 2.44s] -> /content/splits/DMeKRfHu-Tmp077-8fguID/002_bebree.wav
# Saved segment 3: 'Translation:' [2.69s - 3.07s] -> /content/splits/DMeKRfHu-Tmp077-8fguID/003_Translation:.wav
# Saved segment 4: 'Give' [3.21s - 3.32s] -> /content/splits/DMeKRfHu-Tmp077-8fguID/004_Give.wav
# Saved segment 5: 'me' [3.38s - 3.44s] -> /content/splits/DMeKRfHu-Tmp077-8fguID/005_me.wav
# Saved segment 6: 'more' [3.49s - 3.55s] -> /content/splits/DMeKRfHu-Tmp077-8fguID/006_more.wav
# Processing pair: JA5ALLPK-Tmp002-AwLGzp.wav + JA5ALLPK-Tmp002-AwLGzp.txt
# Saved segment 0: 'Transcription:' [0.86s - 1.34s] -> /content/splits/JA5ALLPK-Tmp002-AwLGzp/000_Transcription:.wav
# Saved segment 1: 'Woadi' [1.39s - 1.51s] -> /content/splits/JA5ALLPK-Tmp002-AwLGzp/001_Woadi.wav
# Saved segment 2: 'Ńkɔmmɔ' [1.55s - 1.85s] -> /content/splits/JA5ALLPK-Tmp002-AwLGzp/002_Ńkɔmmɔ.wav
# Saved segment 3: 'mprɛnsa' [1.89s - 2.04s] -> /content/splits/JA5ALLPK-Tmp002-AwLGzp/003_mprɛnsa.wav
# Saved segment 4: 'Translation:' [2.08s - 2.35s] -> /content/splits/JA5ALLPK-Tmp002-AwLGzp/004_Translation:.wav
# Saved segment 5: 'He' [2.39s - 2.42s] -> /content/splits/JA5ALLPK-Tmp002-AwLGzp/005_He.wav
# Saved segment 6: 'has' [2.46s - 2.50s] -> /content/splits/JA5ALLPK-Tmp002-AwLGzp/006_has.wav
# Saved segment 7: 'conversed' [2.54s - 2.71s] -> /content/splits/JA5ALLPK-Tmp002-AwLGzp/007_conversed.wav
# Saved segment 8: 'three' [2.75s - 2.86s] -> /content/splits/JA5ALLPK-Tmp002-AwLGzp/008_three.wav
# Saved segment 9: 'times' [2.90s - 3.04s] -> /content/splits/JA5ALLPK-Tmp002-AwLGzp/009_times.wav
# Processing pair: HM7MwN94-Tmp090-XL5nA4.wav + HM7MwN94-Tmp090-XL5nA4.txt
# Saved segment 0: 'Transcription:' [0.02s - 1.18s] -> /content/splits/HM7MwN94-Tmp090-XL5nA4/000_Transcription:.wav
# Saved segment 1: 'Me' [1.22s - 1.26s] -> /content/splits/HM7MwN94-Tmp090-XL5nA4/001_Me.wav
# Saved segment 2: 'ho' [1.32s - 1.34s] -> /content/splits/HM7MwN94-Tmp090-XL5nA4/002_ho.wav
# Saved segment 3: 'yɛ' [1.39s - 1.41s] -> /content/splits/HM7MwN94-Tmp090-XL5nA4/003_yɛ.wav
# Saved segment 4: 'paa' [1.49s - 1.95s] -> /content/splits/HM7MwN94-Tmp090-XL5nA4/004_paa.wav
# Saved segment 5: 'Translation:' [2.14s - 2.44s] -> /content/splits/HM7MwN94-Tmp090-XL5nA4/005_Translation:.wav
# Saved segment 6: 'I' [2.48s - 2.48s] -> /content/splits/HM7MwN94-Tmp090-XL5nA4/006_I.wav
# Saved segment 7: 'am' [2.54s - 2.56s] -> /content/splits/HM7MwN94-Tmp090-XL5nA4/007_am.wav
# Saved segment 8: 'very' [2.60s - 2.71s] -> /content/splits/HM7MwN94-Tmp090-XL5nA4/008_very.wav
# Saved segment 9: 'well' [2.79s - 2.98s] -> /content/splits/HM7MwN94-Tmp090-XL5nA4/009_well.wav
# Processing pair: FA5lyzBU-Tmp124-s84UnX.wav + FA5lyzBU-Tmp124-s84UnX.txt
# Saved segment 0: 'Transcription:' [0.02s - 0.99s] -> /content/splits/FA5lyzBU-Tmp124-s84UnX/000_Transcription:.wav
# Saved segment 1: 'To' [2.21s - 2.35s] -> /content/splits/FA5lyzBU-Tmp124-s84UnX/001_To.wav
# Saved segment 2: 'so' [2.46s - 2.54s] -> /content/splits/FA5lyzBU-Tmp124-s84UnX/002_so.wav
# Saved segment 3: 'ma' [2.67s - 2.75s] -> /content/splits/FA5lyzBU-Tmp124-s84UnX/003_ma.wav
# Saved segment 4: 'me' [2.86s - 2.94s] -> /content/splits/FA5lyzBU-Tmp124-s84UnX/004_me.wav
# Saved segment 5: 'Translation:' [3.09s - 3.32s] -> /content/splits/FA5lyzBU-Tmp124-s84UnX/005_Translation:.wav
# Saved segment 6: 'Add' [3.36s - 3.42s] -> /content/splits/FA5lyzBU-Tmp124-s84UnX/006_Add.wav
# Saved segment 7: 'some' [3.46s - 3.59s] -> /content/splits/FA5lyzBU-Tmp124-s84UnX/007_some.wav
# Saved segment 8: 'more' [3.63s - 3.78s] -> /content/splits/FA5lyzBU-Tmp124-s84UnX/008_more.wav
# Processing pair: SKUDJnDU-Tmp112-Gdy1mi.wav + SKUDJnDU-Tmp112-Gdy1mi.txt
# Saved segment 0: 'Transcription:' [0.71s - 1.03s] -> /content/splits/SKUDJnDU-Tmp112-Gdy1mi/000_Transcription:.wav
# Saved segment 1: 'Boa' [2.35s - 2.54s] -> /content/splits/SKUDJnDU-Tmp112-Gdy1mi/001_Boa.wav
# Saved segment 2: 'me' [2.65s - 2.73s] -> /content/splits/SKUDJnDU-Tmp112-Gdy1mi/002_me.wav
# Saved segment 3: 'Translation:' [2.81s - 3.02s] -> /content/splits/SKUDJnDU-Tmp112-Gdy1mi/003_Translation:.wav
# Saved segment 4: 'Help' [3.07s - 3.13s] -> /content/splits/SKUDJnDU-Tmp112-Gdy1mi/004_Help.wav
# Saved segment 5: 'me' [3.17s - 3.19s] -> /content/splits/SKUDJnDU-Tmp112-Gdy1mi/005_me.wav
# Processing pair: GA6XjFAL-Tmp099-EzawJc.wav + GA6XjFAL-Tmp099-EzawJc.txt
# Saved segment 0: 'Transcription:' [0.73s - 1.24s] -> /content/splits/GA6XjFAL-Tmp099-EzawJc/000_Transcription:.wav
# Saved segment 1: 'Kosɛ,' [1.28s - 1.45s] -> /content/splits/GA6XjFAL-Tmp099-EzawJc/001_Kosɛ,.wav
# Saved segment 2: 'manhyɛ' [1.57s - 2.14s] -> /content/splits/GA6XjFAL-Tmp099-EzawJc/002_manhyɛ.wav
# Saved segment 3: 'da' [2.27s - 2.29s] -> /content/splits/GA6XjFAL-Tmp099-EzawJc/003_da.wav
# Saved segment 4: 'Translation:' [2.37s - 2.69s] -> /content/splits/GA6XjFAL-Tmp099-EzawJc/004_Translation:.wav
# Saved segment 5: 'Sorry,' [2.73s - 2.94s] -> /content/splits/GA6XjFAL-Tmp099-EzawJc/005_Sorry,.wav
# Saved segment 6: 'it' [2.98s - 3.00s] -> /content/splits/GA6XjFAL-Tmp099-EzawJc/006_it.wav
# Saved segment 7: 'was' [3.04s - 3.11s] -> /content/splits/GA6XjFAL-Tmp099-EzawJc/007_was.wav
# Saved segment 8: 'not' [3.15s - 3.21s] -> /content/splits/GA6XjFAL-Tmp099-EzawJc/008_not.wav
# Saved segment 9: 'intentional' [3.25s - 3.53s] -> /content/splits/GA6XjFAL-Tmp099-EzawJc/009_intentional.wav
# Processing pair: SA1nhEic-Tmp017-N9B8fp.wav + SA1nhEic-Tmp017-N9B8fp.txt
# Saved segment 0: 'Transcription:' [0.02s - 0.94s] -> /content/splits/SA1nhEic-Tmp017-N9B8fp/000_Transcription:.wav
# Saved segment 1: 'Ɛsoo' [0.99s - 1.13s] -> /content/splits/SA1nhEic-Tmp017-N9B8fp/001_Ɛsoo.wav
# Saved segment 2: 'aba' [1.18s - 1.24s] -> /content/splits/SA1nhEic-Tmp017-N9B8fp/002_aba.wav
# Saved segment 3: 'pii' [1.28s - 1.34s] -> /content/splits/SA1nhEic-Tmp017-N9B8fp/003_pii.wav
# Saved segment 4: 'Translation:' [1.41s - 1.70s] -> /content/splits/SA1nhEic-Tmp017-N9B8fp/004_Translation:.wav
# Saved segment 5: 'It' [1.74s - 1.76s] -> /content/splits/SA1nhEic-Tmp017-N9B8fp/005_It.wav
# Saved segment 6: 'bore' [1.87s - 1.95s] -> /content/splits/SA1nhEic-Tmp017-N9B8fp/006_bore.wav
# Saved segment 7: 'much' [2.00s - 2.06s] -> /content/splits/SA1nhEic-Tmp017-N9B8fp/007_much.wav
# Saved segment 8: 'fruit' [2.10s - 2.21s] -> /content/splits/SA1nhEic-Tmp017-N9B8fp/008_fruit.wav
# Processing pair: DAyVUBH2-Tmp087-Sr8Zux.wav + DAyVUBH2-Tmp087-Sr8Zux.txt
# Saved segment 0: 'Transcription:' [0.36s - 0.82s] -> /content/splits/DAyVUBH2-Tmp087-Sr8Zux/000_Transcription:.wav
# Saved segment 1: 'Yeinom' [0.86s - 0.97s] -> /content/splits/DAyVUBH2-Tmp087-Sr8Zux/001_Yeinom.wav
# Saved segment 2: 'nyinaa' [1.07s - 1.28s] -> /content/splits/DAyVUBH2-Tmp087-Sr8Zux/002_nyinaa.wav
# Saved segment 3: 'yɛ' [1.32s - 1.34s] -> /content/splits/DAyVUBH2-Tmp087-Sr8Zux/003_yɛ.wav
# Saved segment 4: 'wo' [1.39s - 1.41s] -> /content/splits/DAyVUBH2-Tmp087-Sr8Zux/004_wo.wav
# Saved segment 5: 'dea' [1.45s - 1.49s] -> /content/splits/DAyVUBH2-Tmp087-Sr8Zux/005_dea.wav
# Saved segment 6: 'Translation:' [1.62s - 1.87s] -> /content/splits/DAyVUBH2-Tmp087-Sr8Zux/006_Translation:.wav
# Saved segment 7: 'These' [1.95s - 2.04s] -> /content/splits/DAyVUBH2-Tmp087-Sr8Zux/007_These.wav
# Saved segment 8: 'are' [2.08s - 2.12s] -> /content/splits/DAyVUBH2-Tmp087-Sr8Zux/008_are.wav
# Saved segment 9: 'all' [2.16s - 2.23s] -> /content/splits/DAyVUBH2-Tmp087-Sr8Zux/009_all.wav
# Saved segment 10: 'for' [2.27s - 2.31s] -> /content/splits/DAyVUBH2-Tmp087-Sr8Zux/010_for.wav
# Saved segment 11: 'you' [2.35s - 2.92s] -> /content/splits/DAyVUBH2-Tmp087-Sr8Zux/011_you.wav
# Processing pair: BAJ9x9Kj-Tmp073-Dc0Ysq.wav + BAJ9x9Kj-Tmp073-Dc0Ysq.txt
# Saved segment 0: 'Transcription:' [3.44s - 3.84s] -> /content/splits/BAJ9x9Kj-Tmp073-Dc0Ysq/000_Transcription:.wav
# Saved segment 1: 'Hwan' [3.91s - 3.97s] -> /content/splits/BAJ9x9Kj-Tmp073-Dc0Ysq/001_Hwan.wav
# Saved segment 2: 'akonnwa' [4.01s - 4.45s] -> /content/splits/BAJ9x9Kj-Tmp073-Dc0Ysq/002_akonnwa.wav
# Saved segment 3: 'Translation:' [4.49s - 4.89s] -> /content/splits/BAJ9x9Kj-Tmp073-Dc0Ysq/003_Translation:.wav
# Saved segment 4: 'Whose' [4.96s - 5.21s] -> /content/splits/BAJ9x9Kj-Tmp073-Dc0Ysq/004_Whose.wav
# Saved segment 5: 'chair' [5.29s - 5.82s] -> /content/splits/BAJ9x9Kj-Tmp073-Dc0Ysq/005_chair.wav
# Processing pair: PAHO4JO8-Tmp104-PW1NgJ.wav + PAHO4JO8-Tmp104-PW1NgJ.txt
# Saved segment 0: 'Transcription:' [1.74s - 5.10s] -> /content/splits/PAHO4JO8-Tmp104-PW1NgJ/000_Transcription:.wav
# Saved segment 1: 'Wote' [5.14s - 5.21s] -> /content/splits/PAHO4JO8-Tmp104-PW1NgJ/001_Wote.wav
# Saved segment 2: 'borɔfo' [5.25s - 5.36s] -> /content/splits/PAHO4JO8-Tmp104-PW1NgJ/002_borɔfo.wav
# Saved segment 3: 'Translation:' [5.40s - 5.80s] -> /content/splits/PAHO4JO8-Tmp104-PW1NgJ/003_Translation:.wav
# Saved segment 4: 'Do' [5.84s - 5.86s] -> /content/splits/PAHO4JO8-Tmp104-PW1NgJ/004_Do.wav
# Saved segment 5: 'you' [5.94s - 6.03s] -> /content/splits/PAHO4JO8-Tmp104-PW1NgJ/005_you.wav
# Saved segment 6: 'understand' [6.07s - 6.26s] -> /content/splits/PAHO4JO8-Tmp104-PW1NgJ/006_understand.wav
# Saved segment 7: 'english' [6.30s - 7.27s] -> /content/splits/PAHO4JO8-Tmp104-PW1NgJ/007_english.wav
# Processing pair: KOQdPViN-Tmp126-dZ57nn.wav + KOQdPViN-Tmp126-dZ57nn.txt
# Saved segment 0: 'Transcription:' [0.80s - 1.05s] -> /content/splits/KOQdPViN-Tmp126-dZ57nn/000_Transcription:.wav
# Saved segment 1: 'ɛyɛ' [2.62s - 2.81s] -> /content/splits/KOQdPViN-Tmp126-dZ57nn/001_ɛyɛ.wav
# Saved segment 2: 'fɛ' [3.00s - 3.11s] -> /content/splits/KOQdPViN-Tmp126-dZ57nn/002_fɛ.wav
# Saved segment 3: 'Translation:' [3.55s - 3.76s] -> /content/splits/KOQdPViN-Tmp126-dZ57nn/003_Translation:.wav
# Saved segment 4: 'It' [3.82s - 3.84s] -> /content/splits/KOQdPViN-Tmp126-dZ57nn/004_It.wav
# Saved segment 5: 'is' [3.93s - 3.95s] -> /content/splits/KOQdPViN-Tmp126-dZ57nn/005_is.wav
# Saved segment 6: 'beautiful' [3.99s - 4.16s] -> /content/splits/KOQdPViN-Tmp126-dZ57nn/006_beautiful.wav
# Processing pair: CAPRjwVE-Tmp101-rdkOTW.wav + CAPRjwVE-Tmp101-rdkOTW.txt
# Saved segment 0: 'Transcription:' [0.06s - 0.40s] -> /content/splits/CAPRjwVE-Tmp101-rdkOTW/000_Transcription:.wav
# Saved segment 1: 'Aane' [0.44s - 0.61s] -> /content/splits/CAPRjwVE-Tmp101-rdkOTW/001_Aane.wav
# Saved segment 2: 'Translation:' [0.65s - 0.90s] -> /content/splits/CAPRjwVE-Tmp101-rdkOTW/002_Translation:.wav
# Saved segment 3: 'Yes' [0.94s - 1.03s] -> /content/splits/CAPRjwVE-Tmp101-rdkOTW/003_Yes.wav
# Processing pair: FA5lyzBU-Tmp011-Xu2az9.wav + FA5lyzBU-Tmp011-Xu2az9.txt
# Saved segment 0: 'Transcription:' [1.28s - 2.75s] -> /content/splits/FA5lyzBU-Tmp011-Xu2az9/000_Transcription:.wav
# Saved segment 1: 'Ɔmee' [2.79s - 3.11s] -> /content/splits/FA5lyzBU-Tmp011-Xu2az9/001_Ɔmee.wav
# Saved segment 2: 'ne' [3.17s - 3.19s] -> /content/splits/FA5lyzBU-Tmp011-Xu2az9/002_ne.wav
# Saved segment 3: 'Ɛfeɛ' [3.23s - 3.36s] -> /content/splits/FA5lyzBU-Tmp011-Xu2az9/003_Ɛfeɛ.wav
# Saved segment 4: 'Translation:' [3.40s - 3.61s] -> /content/splits/FA5lyzBU-Tmp011-Xu2az9/004_Translation:.wav
# Saved segment 5: 'Satisfaction' [3.65s - 3.97s] -> /content/splits/FA5lyzBU-Tmp011-Xu2az9/005_Satisfaction.wav
# Saved segment 6: 'and' [4.05s - 4.09s] -> /content/splits/FA5lyzBU-Tmp011-Xu2az9/006_and.wav
# Saved segment 7: 'throwing' [4.14s - 4.39s] -> /content/splits/FA5lyzBU-Tmp011-Xu2az9/007_throwing.wav
# Saved segment 8: 'up' [4.43s - 4.56s] -> /content/splits/FA5lyzBU-Tmp011-Xu2az9/008_up.wav
# Processing pair: JAUoU3hu-Tmp009-F3YhyL.wav + JAUoU3hu-Tmp009-F3YhyL.txt
# Saved segment 0: 'Transcription:' [0.08s - 0.88s] -> /content/splits/JAUoU3hu-Tmp009-F3YhyL/000_Transcription:.wav
# Saved segment 1: 'Wɔ' [0.92s - 0.97s] -> /content/splits/JAUoU3hu-Tmp009-F3YhyL/001_Wɔ.wav
# Saved segment 2: 'nnwomkorɔ' [1.01s - 1.26s] -> /content/splits/JAUoU3hu-Tmp009-F3YhyL/002_nnwomkorɔ.wav
# Saved segment 3: 'kuo' [1.30s - 1.36s] -> /content/splits/JAUoU3hu-Tmp009-F3YhyL/003_kuo.wav
# Saved segment 4: 'bi' [1.41s - 1.45s] -> /content/splits/JAUoU3hu-Tmp009-F3YhyL/004_bi.wav
# Saved segment 5: 'mu' [1.49s - 1.51s] -> /content/splits/JAUoU3hu-Tmp009-F3YhyL/005_mu.wav
# Saved segment 6: 'Translation:' [1.57s - 1.87s] -> /content/splits/JAUoU3hu-Tmp009-F3YhyL/006_Translation:.wav
# Saved segment 7: 'In' [1.91s - 1.93s] -> /content/splits/JAUoU3hu-Tmp009-F3YhyL/007_In.wav
# Saved segment 8: 'a' [1.97s - 1.97s] -> /content/splits/JAUoU3hu-Tmp009-F3YhyL/008_a.wav
# Saved segment 9: 'certain' [2.02s - 2.14s] -> /content/splits/JAUoU3hu-Tmp009-F3YhyL/009_certain.wav
# Saved segment 10: 'singing' [2.18s - 2.31s] -> /content/splits/JAUoU3hu-Tmp009-F3YhyL/010_singing.wav
# Saved segment 11: 'group' [2.35s - 3.55s] -> /content/splits/JAUoU3hu-Tmp009-F3YhyL/011_group.wav
# Processing pair: GOmeq57b-Tmp049-VBwkD1.wav + GOmeq57b-Tmp049-VBwkD1.txt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-2-2877350565.py in <cell line: 0>()
#      65
#      66     # Preprocess text
# ---> 67     tokens_starred, text_starred = preprocess_text(
#      68         text,
#      69         romanize=True,
#
# /usr/local/lib/python3.11/dist-packages/ctc_forced_aligner/text_utils.py in preprocess_text(text, romanize, language, split_size, star_frequency)
#     220
#     221     if romanize:
# --> 222         tokens = get_uroman_tokens(norm_text, language)
#     223     else:
#     224         tokens = [" ".join(list(word)) for word in norm_text]
#
# /usr/local/lib/python3.11/dist-packages/ctc_forced_aligner/text_utils.py in get_uroman_tokens(norm_transcripts, iso)
#     165         cmd.extend(["-l", iso])
#     166
# --> 167     result = subprocess.run(
#     168         cmd,
#     169         input=input_text,
#
# /usr/lib/python3.11/subprocess.py in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     548     with Popen(*popenargs, **kwargs) as process:
#     549         try:
# --> 550             stdout, stderr = process.communicate(input, timeout=timeout)
#     551         except TimeoutExpired as exc:
#     552             process.kill()
#
# /usr/lib/python3.11/subprocess.py in communicate(self, input, timeout)
#    1207
#    1208             try:
# -> 1209                 stdout, stderr = self._communicate(input, endtime, timeout)
#    1210             except KeyboardInterrupt:
#    1211                 # https://bugs.python.org/issue25942
#
# /usr/lib/python3.11/subprocess.py in _communicate(self, input, endtime, orig_timeout)
#    2113                             'failed to raise TimeoutExpired.')
#    2114
# -> 2115                     ready = selector.select(timeout)
#    2116                     self._check_timeout(endtime, orig_timeout, stdout, stderr)
#    2117
#
# /usr/lib/python3.11/selectors.py in select(self, timeout)
#     413         ready = []
#     414         try:
# --> 415             fd_event_list = self._selector.poll(timeout)
#     416         except InterruptedError:
#     417             return ready
#
# KeyboardInterrupt:
